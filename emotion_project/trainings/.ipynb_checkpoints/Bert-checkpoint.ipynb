# %%
import re
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
from nltk import PorterStemmer, word_tokenize
from nltk.corpus import stopwords
import unidecode
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.nn.functional import softmax
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import AdamW
from tqdm import tqdm
import torch

# %%
train_data = pd.read_csv('data/wassa_train.csv')
test_data = pd.read_csv('data/wassa_test.csv')
val_data = pd.read_csv('data/wassa_val.csv')

# %%
train_data
# Out:
#         id                                              tweet  emotion
# 0     1929  Kinda wished I watched mischievous kiss before...      joy
# 1     4049  When you forget to mention you were bought dre...    anger
# 2     5405  @FreyaLynn @donniewahlberg yep! jimmy buffett ...  neutral
# 3     5900  @philcampbell blue skies? where, it's still gr...  neutral
# 4     3712  Some moving clips on youtube tonight of the vi...    anger
# ...    ...                                                ...      ...
# 5996  5407  @koifusionpdx i was so close to the tacos...on...  neutral
# 5997   496  @Fatumoriginal there's no sitcom better! If u ...  sadness
# 5998   499  @Mysteri759 @Ren102e906 @slb42jcb @swoozyqyah ...  sadness
# 5999  1784  Watch this amazing live.ly broadcast by @ittzd...      joy
# 6000  4829            @daniellemhicks lol what!! where is it!  neutral
#
# [6001 rows x 3 columns]

# %%
def preprocess_text(text):
    result = text.lower()
    result = result.strip()
    result = re.result = re.sub(r"http\S+", "", result)
    result = re.sub('\S*@\S*\s?', '', result)
    result = unidecode.unidecode(result)
    stop_words = stopwords.words("english")
    word_list = word_tokenize(result)
    # # english stemmer
    # ps = SnowballStemmer("english")

    stemmed_sentence = ""
    for word in word_list:
        if word not in stop_words:
            stemmed_sentence += word
            stemmed_sentence += " "

    result = stemmed_sentence
    whitelist = set('abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ')
    result = ''.join(filter(whitelist.__contains__, result))
    result = ''.join([i for i in result if not i.isdigit()])
    return result

# %%
def preprocess_text_list(text_list):
  for i,text in enumerate(text_list):
    text_list[i] = preprocess_text(text_list[i])

# %%
train_texts = train_data["tweet"].tolist()
val_texts = val_data["tweet"].tolist()
test_texts = test_data["tweet"].tolist()


train_labels = train_data["emotion"].tolist()
val_labels = val_data["emotion"].tolist()
test_labels = test_data["emotion"].tolist()

train_labels[:10]
# Out:
# ['joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral']

# %%
preprocess_text_list(train_texts)
preprocess_text_list(val_texts)
preprocess_text_list(test_texts)

train_texts[:10]
# Out:
# ['kinda wished watched mischievous kiss playful kiss ',
#  'forget mention bought dreamboys tickets ',
#  'yep  jimmy buffett ftw     jimmy needs tweet words wisdom every morning ',
#  'blue skies   s still grey hazy window ',
#  'moving clips youtube tonight vigil held tulsa metropolitan baptist church  terencecruther  justice  sadness ',
#  'makes successful  happy forever ',
#  'morning hon  breakfast  cant decide ',
#  'standard candice starting show pout  startasyoumeantogoon  gbbo ',
#  '   would frown bit  folding arms  why every time m need assistance someone expects lil   ',
#  'someone make cofffeeeeeee  ']

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
train_encodings = tokenizer(train_texts, truncation=True, padding=True, return_tensors='pt', max_length=512)
val_encodings = tokenizer(val_texts, truncation=True, padding=True, return_tensors='pt', max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, return_tensors='pt', max_length=512)

# %%
label_encoder = LabelEncoder()
encoded_train_labels = label_encoder.fit_transform(train_labels)
encoded_val_labels = label_encoder.transform(val_labels)
encoded_test_labels = label_encoder.transform(test_labels)

# %%
train_labels_tensor = torch.tensor(label_encoder.transform(train_labels))
val_labels_tensor = torch.tensor(label_encoder.transform(val_labels))
test_labels_tensor = torch.tensor(label_encoder.transform(test_labels))

# %%
# bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(set(train_labels)))
# bert_model.train_model(train_encodings, train_labels_tensor)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

train_encodings = tokenizer(train_texts, truncation=True, padding=True, return_tensors='pt', max_length=512)
val_encodings = tokenizer(val_texts, truncation=True, padding=True, return_tensors='pt', max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, return_tensors='pt', max_length=512)

train_labels_tensor = torch.tensor(label_encoder.transform(train_labels))
val_labels_tensor = torch.tensor(label_encoder.transform(val_labels))
test_labels_tensor = torch.tensor(label_encoder.transform(test_labels))

train_dataset = TensorDataset(train_encodings['input_ids'], train_encodings['attention_mask'], train_labels_tensor)
val_dataset = TensorDataset(val_encodings['input_ids'], val_encodings['attention_mask'], val_labels_tensor)
test_dataset = TensorDataset(test_encodings['input_ids'], test_encodings['attention_mask'], test_labels_tensor)

batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
optimizer = AdamW(bert_model.parameters(), lr=2e-5)
num_epochs = 3

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bert_model.to(device)

for epoch in range(num_epochs):
    bert_model.train()
    train_loss = 0.0
    for batch in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)
        
        labels = labels.to(dtype=torch.long)
        
        optimizer.zero_grad()
        outputs = bert_model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

    average_train_loss = train_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Average Training Loss: {average_train_loss}")

bert_model.eval()
predictions_proba_bert = []
with torch.no_grad():
    for batch in tqdm(test_loader, desc=f"Testing"):
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)
        outputs = bert_model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predictions_proba_bert.extend(softmax(logits, dim=1).cpu().numpy())

predicted_emotions_bert = [label_encoder.classes_[idx] for idx in torch.argmax(torch.tensor(predictions_proba_bert), axis=1)]
probabilities_bert = torch.max(torch.tensor(predictions_proba_bert), dim=1).values.numpy()
# Out:
# Epoch 1/3: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 751/751 [21:32<00:00,  1.72s/it]
# Epoch 1/3, Average Training Loss: 0.8336163525297225
# Epoch 2/3: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 751/751 [21:32<00:00,  1.72s/it]
# Epoch 2/3, Average Training Loss: 0.3539381942410424
# Epoch 3/3: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 751/751 [21:19<00:00,  1.70s/it]
# Epoch 3/3, Average Training Loss: 0.22889629928903596
# Testing: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 94/94 [00:36<00:00,  2.59it/s]
# C:\Users\Julia\AppData\Local\Temp\ipykernel_1016\2107867781.py:39: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:264.)
#   predicted_emotions_bert = [label_encoder.classes_[idx] for idx in torch.argmax(torch.tensor(predictions_proba_bert), axis=1)]

# %%
result, model_outputs, wrong_predictions = bert_model.eval_model(val_encodings, val_labels_tensor)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 result, model_outputs, wrong_predictions = bert_model.eval_model(val_encodings, val_labels_tensor)
#
# File ~\PycharmProjects\react-try\venv\Lib\site-packages\torch\nn\modules\module.py:1695, in Module.__getattr__(self, name)
#    1693     if name in modules:
#    1694         return modules[name]
# -> 1695 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'BertForSequenceClassification' object has no attribute 'eval_model'

# %%
result, model_outputs, wrong_predictions = bert_model.eval(test_encodings, test_labels_tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result, model_outputs, wrong_predictions = bert_model.eval(test_encodings, test_labels_tensor)
#
# NameError: name 'bert_model' is not defined

# %%
bert_model.eval()

with torch.no_grad():
    outputs = bert_model(**test_encodings)

    logits = outputs.logits

    probabilities = softmax(logits, dim=1)

    predicted_labels = torch.argmax(probabilities, dim=1)

predicted_labels_np = predicted_labels.cpu().numpy()
test_labels_np = test_labels_tensor.cpu().numpy()

accuracy = accuracy_score(test_labels_np, predicted_labels_np)
classification_rep = classification_report(test_labels_np, predicted_labels_np)

print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.8466666666666667
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       150
#            1       0.82      0.82      0.82       150
#            2       0.88      0.89      0.89       150
#            3       0.85      0.75      0.80       150
#            4       0.89      0.89      0.89       150
#
#     accuracy                           0.85       750
#    macro avg       0.85      0.85      0.85       750
# weighted avg       0.85      0.85      0.85       750

# %%
from torch.nn.functional import softmax

bert_model.eval()

with torch.no_grad():
    outputs = bert_model(**test_encodings)

    logits = outputs.logits

    probabilities = softmax(logits, dim=1)

probabilities_np = probabilities.cpu().numpy()
predicted_labels_np = torch.argmax(probabilities, dim=1).cpu().numpy()
test_labels_np = test_labels_tensor.cpu().numpy()

for i, text in enumerate(test_texts):
    print(f"Text: {text}")
    for j, emotion in enumerate(label_encoder.classes_):
        print(f"Probability of {emotion}: {probabilities_np[i, j]}")
    print("Predicted Emotion:", label_encoder.classes_[predicted_labels_np[i]])
    print("True Emotion:", label_encoder.classes_[test_labels_np[i]])
    print("\n")
# Out:
# Text:  depression
# Probability of anger: 0.0007440547924488783
# Probability of fear: 0.00170200876891613
# Probability of joy: 0.0008754062000662088
# Probability of neutral: 0.0022933082655072212
# Probability of sadness: 0.9943852424621582
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: peanut butter takes away sting
# Probability of anger: 0.9940640330314636
# Probability of fear: 0.00229828548617661
# Probability of joy: 0.0013073324225842953
# Probability of neutral: 0.0018136358121410012
# Probability of sadness: 0.0005166358314454556
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: mannnn  got iphone    im jealous
# Probability of anger: 0.8905501365661621
# Probability of fear: 0.00770144397392869
# Probability of joy: 0.011092078872025013
# Probability of neutral: 0.08641061931848526
# Probability of sadness: 0.004245731048285961
# Predicted Emotion: anger
# True Emotion: neutral
#
#
# Text: speech bold coz nt written pm ns bt expressiontone dull n dim
# Probability of anger: 0.0012955290731042624
# Probability of fear: 0.0016702497377991676
# Probability of joy: 0.0020636499393731356
# Probability of neutral: 0.001211856841109693
# Probability of sadness: 0.9937586784362793
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: fair
# Probability of anger: 0.0948353186249733
# Probability of fear: 0.05125497654080391
# Probability of joy: 0.04834926873445511
# Probability of neutral: 0.7396190166473389
# Probability of sadness: 0.06594139337539673
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: may send copy  herothegreyhound  either ebook real paper one  boy greyhound  smiles  tears  laughter
# Probability of anger: 0.0017489250749349594
# Probability of fear: 0.0017841033404693007
# Probability of joy: 0.9947817921638489
# Probability of neutral: 0.000765907287131995
# Probability of sadness: 0.0009191750432364643
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: baby going first sleepover tonight m gon na need lot wine get today
# Probability of anger: 0.002985631115734577
# Probability of fear: 0.006777813192456961
# Probability of joy: 0.004119082819670439
# Probability of neutral: 0.9847079515457153
# Probability of sadness: 0.0014095075894147158
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: stayed home
# Probability of anger: 0.0059304386377334595
# Probability of fear: 0.013197171501815319
# Probability of joy: 0.005873730406165123
# Probability of neutral: 0.9009114503860474
# Probability of sadness: 0.07408718764781952
# Predicted Emotion: neutral
# True Emotion: sadness
#
#
# Text: tomorrowland central nt gotten confirmation m signed star tours  waiting see give shift
# Probability of anger: 0.06866860389709473
# Probability of fear: 0.0660918653011322
# Probability of joy: 0.34032490849494934
# Probability of neutral: 0.41290199756622314
# Probability of sadness: 0.11201255768537521
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: guy video m shaking
# Probability of anger: 0.0017130619380623102
# Probability of fear: 0.9930643439292908
# Probability of joy: 0.0010709150228649378
# Probability of neutral: 0.003186410292983055
# Probability of sadness: 0.0009653279557824135
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: cancelling home fibe  internet tv afternoon  soon arrange alternate internet    angry  fedup
# Probability of anger: 0.9953088164329529
# Probability of fear: 0.0022532977163791656
# Probability of joy: 0.0007626597071066499
# Probability of neutral: 0.001154253026470542
# Probability of sadness: 0.0005210222443565726
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: literally guy  somewouldsaysuccessful guy  tell this ship sail  kay guy  first  re working sub  last  sunk
# Probability of anger: 0.0017595781246200204
# Probability of fear: 0.006351588759571314
# Probability of joy: 0.0022805763874202967
# Probability of neutral: 0.0008802746306173503
# Probability of sadness: 0.9887279272079468
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: feels like lost best friend  lost  fml  missingyou
# Probability of anger: 0.003470321884378791
# Probability of fear: 0.002859716536477208
# Probability of joy: 0.0013843640917912126
# Probability of neutral: 0.0054932585917413235
# Probability of sadness: 0.9867923259735107
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: dream dropped iphone  broke tt  cry  iphone
# Probability of anger: 0.609455406665802
# Probability of fear: 0.061563849449157715
# Probability of joy: 0.014098456129431725
# Probability of neutral: 0.29982659220695496
# Probability of sadness: 0.01505570113658905
# Predicted Emotion: anger
# True Emotion: fear
#
#
# Text:  serious  fredsirieix lives peckham  south london s  love guru  big
# Probability of anger: 0.0024848436005413532
# Probability of fear: 0.0014293164713308215
# Probability of joy: 0.0011817885097116232
# Probability of neutral: 0.005111132748425007
# Probability of sadness: 0.9897929430007935
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: pregame nerves settled  l  cheering home guys  aflcatsswans  proudlysydney  goswans
# Probability of anger: 0.0027544782496988773
# Probability of fear: 0.000833278929349035
# Probability of joy: 0.9946743249893188
# Probability of neutral: 0.00038046069676056504
# Probability of sadness: 0.0013574156910181046
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: life s short frowning long
# Probability of anger: 0.0010895164450630546
# Probability of fear: 0.001292264205403626
# Probability of joy: 0.0010046807583421469
# Probability of neutral: 0.0036026365123689175
# Probability of sadness: 0.993010938167572
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: high school remember helping neighbors clean back home greenville  pretty sobering stuff   sadness
# Probability of anger: 0.0008826247649267316
# Probability of fear: 0.0011036655632779002
# Probability of joy: 0.0012401044368743896
# Probability of neutral: 0.001293793087825179
# Probability of sadness: 0.9954798221588135
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: cutting hair allll day wish outside
# Probability of anger: 0.011537288315594196
# Probability of fear: 0.014212519861757755
# Probability of joy: 0.027803458273410797
# Probability of neutral: 0.9398010969161987
# Probability of sadness: 0.006645632907748222
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: accept challenges literally even feel exhilaration victory    george s patton
# Probability of anger: 0.0013191415928304195
# Probability of fear: 0.0004916326142847538
# Probability of joy: 0.9967855215072632
# Probability of neutral: 0.0006154222646728158
# Probability of sadness: 0.0007882466306909919
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: recommended reading  prisoners hate aaron beck
# Probability of anger: 0.3702259063720703
# Probability of fear: 0.5690285563468933
# Probability of joy: 0.003563610604032874
# Probability of neutral: 0.04426174238324165
# Probability of sadness: 0.012920120730996132
# Predicted Emotion: fear
# True Emotion: anger
#
#
# Text:  peoplelikemebecause unknown reason try discourage
# Probability of anger: 0.0024909821804612875
# Probability of fear: 0.0034683593548834324
# Probability of joy: 0.003922600299119949
# Probability of neutral: 0.0007929357816465199
# Probability of sadness: 0.9893250465393066
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: m trying lots pain though
# Probability of anger: 0.21435002982616425
# Probability of fear: 0.014413310214877129
# Probability of joy: 0.01647789590060711
# Probability of neutral: 0.7489399313926697
# Probability of sadness: 0.005818829406052828
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: really want go fright night really nt
# Probability of anger: 0.0011840127408504486
# Probability of fear: 0.9939907789230347
# Probability of joy: 0.0015971364919096231
# Probability of neutral: 0.0020552740897983313
# Probability of sadness: 0.0011728989193215966
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: cnt get   goin ur old messages     gt   gt   gt   gt  help   lt   lt   lt   lt
# Probability of anger: 0.061833929270505905
# Probability of fear: 0.010688677430152893
# Probability of joy: 0.006455519236624241
# Probability of neutral: 0.9143291711807251
# Probability of sadness: 0.00669275363907218
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: anyone know good png compression tool os x  tried pngcrush doesnt run
# Probability of anger: 0.025482123717665672
# Probability of fear: 0.006884293630719185
# Probability of joy: 0.0034798183478415012
# Probability of neutral: 0.9614081382751465
# Probability of sadness: 0.0027456667739897966
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: hey way u make somatic theme leopard  themes installers already shapeshifter independent
# Probability of anger: 0.1315348595380783
# Probability of fear: 0.23996561765670776
# Probability of joy: 0.29894790053367615
# Probability of neutral: 0.31207039952278137
# Probability of sadness: 0.017481129616498947
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: little frustrates much misplacing something  looking keys  hours
# Probability of anger: 0.866101861000061
# Probability of fear: 0.05244605988264084
# Probability of joy: 0.039049308747053146
# Probability of neutral: 0.03640221804380417
# Probability of sadness: 0.006000519264489412
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: perfect illusion  least know   angry  ladygaga  iscalming  mysoul
# Probability of anger: 0.994187593460083
# Probability of fear: 0.002577687380835414
# Probability of joy: 0.0012030362850055099
# Probability of neutral: 0.0012186350068077445
# Probability of sadness: 0.0008130205096676946
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: m type flee adversity discourage  ll always stand strong paint
# Probability of anger: 0.0032664143946021795
# Probability of fear: 0.0025724628940224648
# Probability of joy: 0.0032195583917200565
# Probability of neutral: 0.0006464118487201631
# Probability of sadness: 0.9902951717376709
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: sav tells mom  love  responds oh    sad
# Probability of anger: 0.0013965845573693514
# Probability of fear: 0.0016431347467005253
# Probability of joy: 0.0008410803275182843
# Probability of neutral: 0.0036036099772900343
# Probability of sadness: 0.9925156235694885
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: favourite joyful soul
# Probability of anger: 0.002203851006925106
# Probability of fear: 0.000327051937347278
# Probability of joy: 0.9955419898033142
# Probability of neutral: 0.0006597784231416881
# Probability of sadness: 0.0012673757737502456
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: lot positives tonight  clean sheet  payet got free kick practice  zaza looked lively made lot good runs
# Probability of anger: 0.0013010732363909483
# Probability of fear: 0.0005154073587618768
# Probability of joy: 0.9966741800308228
# Probability of neutral: 0.0007381024770438671
# Probability of sadness: 0.0007712291553616524
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: tom phillips jovial start week s show joe strutting video package quite juxtaposition
# Probability of anger: 0.0015432941727340221
# Probability of fear: 0.0004934063763357699
# Probability of joy: 0.9961701035499573
# Probability of neutral: 0.0006485676858574152
# Probability of sadness: 0.0011447087163105607
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: sorry  offend u griffin
# Probability of anger: 0.9943258166313171
# Probability of fear: 0.0026069229934364557
# Probability of joy: 0.001043309224769473
# Probability of neutral: 0.0013606182765215635
# Probability of sadness: 0.0006633027223870158
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: majority people irritate fuck  cba people ahahah
# Probability of anger: 0.9949195981025696
# Probability of fear: 0.0024996893480420113
# Probability of joy: 0.0007482804358005524
# Probability of neutral: 0.001210873480886221
# Probability of sadness: 0.0006216607289388776
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: sucks  old actually
# Probability of anger: 0.417385458946228
# Probability of fear: 0.1425555944442749
# Probability of joy: 0.037636443972587585
# Probability of neutral: 0.33289608359336853
# Probability of sadness: 0.06952643394470215
# Predicted Emotion: anger
# True Emotion: neutral
#
#
# Text: massive argument alarm today  nt want get  nt know re going fix tomorrow morning
# Probability of anger: 0.005583560094237328
# Probability of fear: 0.989859402179718
# Probability of joy: 0.0017257723957300186
# Probability of neutral: 0.0018316537607461214
# Probability of sadness: 0.0009997091256082058
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: oh noes  hey  s tatoo say
# Probability of anger: 0.11489085108041763
# Probability of fear: 0.049147605895996094
# Probability of joy: 0.03163614869117737
# Probability of neutral: 0.7989088892936707
# Probability of sadness: 0.005416521802544594
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: sick doctors waiting room
# Probability of anger: 0.0047208270989358425
# Probability of fear: 0.019116099923849106
# Probability of joy: 0.004886242561042309
# Probability of neutral: 0.9658204317092896
# Probability of sadness: 0.00545651325955987
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: r u scared present front class  severe anxiety  whats r u sad sometimes   go get ur depression checked imediately
# Probability of anger: 0.0011109112529084086
# Probability of fear: 0.01103314571082592
# Probability of joy: 0.0013183718547224998
# Probability of neutral: 0.0040282090194523335
# Probability of sadness: 0.9825093746185303
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: want monte cristo sandwich sooo  bad
# Probability of anger: 0.005081935785710812
# Probability of fear: 0.008751065470278263
# Probability of joy: 0.002750031417235732
# Probability of neutral: 0.9823637008666992
# Probability of sadness: 0.0010532682063058019
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: got paid vacuum rat poop     never dull day biology department
# Probability of anger: 0.0014308165991678834
# Probability of fear: 0.0005093085346743464
# Probability of joy: 0.0017829120624810457
# Probability of neutral: 0.0028584091924130917
# Probability of sadness: 0.9934185743331909
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: really want read fic found s  serious room full  memes
# Probability of anger: 0.0026863315142691135
# Probability of fear: 0.0008582326117902994
# Probability of joy: 0.001317290123552084
# Probability of neutral: 0.0058887191116809845
# Probability of sadness: 0.9892494678497314
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: assured eventual destruction would  interests public  cheerfully accept   sherlock holmes
# Probability of anger: 0.0021412239875644445
# Probability of fear: 0.0007887944229878485
# Probability of joy: 0.995590329170227
# Probability of neutral: 0.0005634362460114062
# Probability of sadness: 0.000916225602850318
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: u wen ur love cheats u  wen thy nt understand emotions behind anger  constant waiting  u
# Probability of anger: 0.9945971965789795
# Probability of fear: 0.002815450308844447
# Probability of joy: 0.0009324076818302274
# Probability of neutral: 0.0011124595766887069
# Probability of sadness: 0.0005423768307082355
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: seriously need pop curtains matt filming scare bejesus
# Probability of anger: 0.001429069321602583
# Probability of fear: 0.9937120676040649
# Probability of joy: 0.0022598819341510534
# Probability of neutral: 0.001460139057599008
# Probability of sadness: 0.0011388983111828566
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text:  one person ruins season   angry
# Probability of anger: 0.995000422000885
# Probability of fear: 0.00252297124825418
# Probability of joy: 0.0007968281279318035
# Probability of neutral: 0.0011410281294956803
# Probability of sadness: 0.0005386346019804478
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: watch amazing lively broadcast  musically
# Probability of anger: 0.0012026600306853652
# Probability of fear: 0.000532236706931144
# Probability of joy: 0.9968020915985107
# Probability of neutral: 0.0007829889073036611
# Probability of sadness: 0.0006800416158512235
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: says maw day  wan na day sober october way  says ave mer chance movember son   classicmoira  glasgow  sober
# Probability of anger: 0.0008107011090032756
# Probability of fear: 0.000935841875616461
# Probability of joy: 0.0011663802433758974
# Probability of neutral: 0.00119776779320091
# Probability of sadness: 0.9958893656730652
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: ve whole time watching ve lost  glasses   hilarious
# Probability of anger: 0.0022444995120167732
# Probability of fear: 0.0010803296463564038
# Probability of joy: 0.9910207390785217
# Probability of neutral: 0.0015425027813762426
# Probability of sadness: 0.004111895803362131
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: dread think
# Probability of anger: 0.0017963541904464364
# Probability of fear: 0.992709755897522
# Probability of joy: 0.0015585488872602582
# Probability of neutral: 0.002676073694601655
# Probability of sadness: 0.0012592237908393145
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: fucker blocked  years ago question lol  proper holds grudge old joe
# Probability of anger: 0.9949187636375427
# Probability of fear: 0.002335324650630355
# Probability of joy: 0.0008023324771784246
# Probability of neutral: 0.0012731850147247314
# Probability of sadness: 0.0006703377002850175
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: looking forward div  next year  revenge  leictershireaway  therey
# Probability of anger: 0.9940787553787231
# Probability of fear: 0.0024855558294802904
# Probability of joy: 0.0013317791745066643
# Probability of neutral: 0.0014473556075245142
# Probability of sadness: 0.0006564677460119128
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: world drives whoever assessed tenderhearted vulnerable build guards  amp  invigorate raging self defense mechanisms
# Probability of anger: 0.9936435222625732
# Probability of fear: 0.0036281049251556396
# Probability of joy: 0.0011555467499420047
# Probability of neutral: 0.0009101529722101986
# Probability of sadness: 0.0006627521361224353
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: m back elated record fucking shit studio evening
# Probability of anger: 0.0014945475850254297
# Probability of fear: 0.0004490461724344641
# Probability of joy: 0.99652099609375
# Probability of neutral: 0.0007314643007703125
# Probability of sadness: 0.0008040491957217455
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: momma irritate asking questions like gone
# Probability of anger: 0.9947633743286133
# Probability of fear: 0.002622943604364991
# Probability of joy: 0.0007567182765342295
# Probability of neutral: 0.0012136913137510419
# Probability of sadness: 0.0006431853398680687
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: anyone drinks sparkling water demon
# Probability of anger: 0.0026764378417283297
# Probability of fear: 0.0008058275561779737
# Probability of joy: 0.9946909546852112
# Probability of neutral: 0.0010330189252272248
# Probability of sadness: 0.0007937452755868435
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: s political map relentless pursuit power
# Probability of anger: 0.9940489530563354
# Probability of fear: 0.003264232072979212
# Probability of joy: 0.0009055394330061972
# Probability of neutral: 0.0012247952399775386
# Probability of sadness: 0.0005564846214838326
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: easy ride child cries  noh  find  find  nothing  nwe sullen misty moor
# Probability of anger: 0.0007344598998315632
# Probability of fear: 0.0010010143741965294
# Probability of joy: 0.0010267962934449315
# Probability of neutral: 0.00112427887506783
# Probability of sadness: 0.9961134195327759
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: s exactly rabid tub thumper compared mcternan
# Probability of anger: 0.9939291477203369
# Probability of fear: 0.0030827359296381474
# Probability of joy: 0.00111119553912431
# Probability of neutral: 0.0012784735299646854
# Probability of sadness: 0.0005984565941616893
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: aww wish sun  get tan      walks  go meee go meeee
# Probability of anger: 0.011305884458124638
# Probability of fear: 0.034928031265735626
# Probability of joy: 0.01926395110785961
# Probability of neutral: 0.8907140493392944
# Probability of sadness: 0.043787989765405655
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: hes right civil war starts wall wall terrorism nt fancy muzzy s chances
# Probability of anger: 0.0028671480249613523
# Probability of fear: 0.9724305272102356
# Probability of joy: 0.002440018579363823
# Probability of neutral: 0.003709298325702548
# Probability of sadness: 0.018552949652075768
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: nt know heck space time bgt bored
# Probability of anger: 0.033548302948474884
# Probability of fear: 0.00608473364263773
# Probability of joy: 0.0066963545978069305
# Probability of neutral: 0.9432501196861267
# Probability of sadness: 0.010420498438179493
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: transparency openness  dull sell fans group  want verbs like buying  defending  building securing
# Probability of anger: 0.0011434935731813312
# Probability of fear: 0.0011056389193981886
# Probability of joy: 0.0017623885069042444
# Probability of neutral: 0.0008108007023110986
# Probability of sadness: 0.9951776266098022
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: watching rain
# Probability of anger: 0.006084483116865158
# Probability of fear: 0.01859763078391552
# Probability of joy: 0.024740934371948242
# Probability of neutral: 0.9457401037216187
# Probability of sadness: 0.004836805164813995
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: re cheerfully defending group unchecked  armed thugs ve shown history racism  violence  lies
# Probability of anger: 0.0025847272481769323
# Probability of fear: 0.0012089888332411647
# Probability of joy: 0.9946655035018921
# Probability of neutral: 0.0005148372729308903
# Probability of sadness: 0.001025926903821528
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text:  india  afraid  bad  terrorism
# Probability of anger: 0.0012904604664072394
# Probability of fear: 0.9949772953987122
# Probability of joy: 0.0010139343794435263
# Probability of neutral: 0.0016902453498914838
# Probability of sadness: 0.001028131227940321
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: would like know source president s optimism running country  wonder answer curiosity
# Probability of anger: 0.0010311907390132546
# Probability of fear: 0.0005783711094409227
# Probability of joy: 0.9970682263374329
# Probability of neutral: 0.0005131250363774598
# Probability of sadness: 0.0008091165218502283
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: may  alwayshungry nt sunk low yet
# Probability of anger: 0.001075104926712811
# Probability of fear: 0.001216480159200728
# Probability of joy: 0.0013219068059697747
# Probability of neutral: 0.0016301574651151896
# Probability of sadness: 0.9947563409805298
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: carry wayward son ll peace done lay weary head rest nt cry
# Probability of anger: 0.000703035737387836
# Probability of fear: 0.001449592411518097
# Probability of joy: 0.0013733879895880818
# Probability of neutral: 0.0015959126176312566
# Probability of sadness: 0.9948780536651611
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: something needs done people hogging machines  nobody use  machines one time   notfair  whypay
# Probability of anger: 0.6082936525344849
# Probability of fear: 0.35407859086990356
# Probability of joy: 0.009272729977965355
# Probability of neutral: 0.00978408195078373
# Probability of sadness: 0.01857098564505577
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: little girl still holding phone tears pouring eyes
# Probability of anger: 0.9902752637863159
# Probability of fear: 0.004924860317260027
# Probability of joy: 0.002199994632974267
# Probability of neutral: 0.0015887131448835135
# Probability of sadness: 0.001011256012134254
# Predicted Emotion: anger
# True Emotion: neutral
#
#
# Text: tend s going get infections  nnhe s frowning looking  nit must hurt damn
# Probability of anger: 0.0013078406918793917
# Probability of fear: 0.0008845723350532353
# Probability of joy: 0.0008985837339423597
# Probability of neutral: 0.0035135711077600718
# Probability of sadness: 0.9933955073356628
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: finally started  homefronttherevolution  story gameplay     terrible  wasteofmoney
# Probability of anger: 0.043277282267808914
# Probability of fear: 0.9500282406806946
# Probability of joy: 0.0029065676499158144
# Probability of neutral: 0.0016758377896621823
# Probability of sadness: 0.0021120889578014612
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: taking picture   awkward smile  nme picture day   awkward smile  nconclusion  stop smiling    n  pictureday  ornot
# Probability of anger: 0.002203043084591627
# Probability of fear: 0.0032280082814395428
# Probability of joy: 0.9922453761100769
# Probability of neutral: 0.000594053533859551
# Probability of sadness: 0.0017295900033786893
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text:   politicallycorrect  bs  offended assumption usa change visitor   amp  nt like
# Probability of anger: 0.9950148463249207
# Probability of fear: 0.0021383664570748806
# Probability of joy: 0.0005669755628332496
# Probability of neutral: 0.0014144580345600843
# Probability of sadness: 0.0008653082186356187
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: funeral  close casket  want play  call recording completed    lost  podcasting  talkshoe
# Probability of anger: 0.0010362784378230572
# Probability of fear: 0.00304410164244473
# Probability of joy: 0.001334266155026853
# Probability of neutral: 0.0027122364845126867
# Probability of sadness: 0.9918730854988098
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: hangover
# Probability of anger: 0.004258724395185709
# Probability of fear: 0.030957628041505814
# Probability of joy: 0.0059089441783726215
# Probability of neutral: 0.8082941770553589
# Probability of sadness: 0.1505804806947708
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: theyve substituted hood badge gun   public opinion indictment charlotte police   dark  sadtimes  america  race
# Probability of anger: 0.005251559428870678
# Probability of fear: 0.0029021441005170345
# Probability of joy: 0.0016146418638527393
# Probability of neutral: 0.0008355684112757444
# Probability of sadness: 0.9893961548805237
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: heart left long againnn  slight pout turned smile  nnheheh kidding  m fine
# Probability of anger: 0.0010246621677652001
# Probability of fear: 0.0016356713604182005
# Probability of joy: 0.009975220076739788
# Probability of neutral: 0.0013552370946854353
# Probability of sadness: 0.9860091805458069
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: yes  amp  cheering homecoming game
# Probability of anger: 0.0016275120433419943
# Probability of fear: 0.0007746154442429543
# Probability of joy: 0.9961994290351868
# Probability of neutral: 0.0005953001673333347
# Probability of sadness: 0.0008031913312152028
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: bad temperament  hissyfits
# Probability of anger: 0.9642325043678284
# Probability of fear: 0.026776593178510666
# Probability of joy: 0.004660849459469318
# Probability of neutral: 0.003127587493509054
# Probability of sadness: 0.001202515559270978
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text:  smile mean thousand words  also hide thousand  problems   fact  teamfollowback
# Probability of anger: 0.003547762054949999
# Probability of fear: 0.006503957323729992
# Probability of joy: 0.9865944385528564
# Probability of neutral: 0.0006897980347275734
# Probability of sadness: 0.002663996536284685
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: m way busy tired time worry past things regretting  never
# Probability of anger: 0.0020962022244930267
# Probability of fear: 0.993075966835022
# Probability of joy: 0.0018494793912395835
# Probability of neutral: 0.00209826766513288
# Probability of sadness: 0.000880106003023684
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: come bell  ring  want go outside
# Probability of anger: 0.0891636312007904
# Probability of fear: 0.3713805377483368
# Probability of joy: 0.0677197277545929
# Probability of neutral: 0.45820239186286926
# Probability of sadness: 0.013533825986087322
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: thought funny   maybe coincidence  green must official color optimism
# Probability of anger: 0.0012046759948134422
# Probability of fear: 0.0004413246060721576
# Probability of joy: 0.9969111084938049
# Probability of neutral: 0.0004915128811262548
# Probability of sadness: 0.0009514047997072339
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: want starbucks
# Probability of anger: 0.019197573885321617
# Probability of fear: 0.028371699154376984
# Probability of joy: 0.005350125953555107
# Probability of neutral: 0.9458284378051758
# Probability of sadness: 0.0012522191973403096
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: may suggest  meal made beans  onions  amp  garlic  day class   revenge
# Probability of anger: 0.9940794706344604
# Probability of fear: 0.00306526105850935
# Probability of joy: 0.0010007531382143497
# Probability of neutral: 0.001438036561012268
# Probability of sadness: 0.00041650549974292517
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: ca nt feel weekend fever anymore everyday day
# Probability of anger: 0.01228476781398058
# Probability of fear: 0.7810550928115845
# Probability of joy: 0.010459544137120247
# Probability of neutral: 0.19474579393863678
# Probability of sadness: 0.0014547135215252638
# Predicted Emotion: fear
# True Emotion: neutral
#
#
# Text: s first expac since wrath feels like proper evolution  game
# Probability of anger: 0.9922540187835693
# Probability of fear: 0.0047568087466061115
# Probability of joy: 0.0011925713624805212
# Probability of neutral: 0.0012181453639641404
# Probability of sadness: 0.0005784576642327011
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: work today  went shopping  relaxing  amp  learning toefl
# Probability of anger: 0.04763370752334595
# Probability of fear: 0.02557486668229103
# Probability of joy: 0.25259268283843994
# Probability of neutral: 0.6593760251998901
# Probability of sadness: 0.014822765253484249
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text:  people country  million  going ruin whole country  people
# Probability of anger: 0.7785142660140991
# Probability of fear: 0.20944097638130188
# Probability of joy: 0.003219041507691145
# Probability of neutral: 0.0037814562674611807
# Probability of sadness: 0.005044182762503624
# Predicted Emotion: anger
# True Emotion: fear
#
#
# Text: prepurchased tickets sent soon  coming saturday evening show  tickets show   panic  hoys
# Probability of anger: 0.0021139592863619328
# Probability of fear: 0.9940738081932068
# Probability of joy: 0.0013179256347939372
# Probability of neutral: 0.0016516096657142043
# Probability of sadness: 0.000842844310682267
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: s brilliant  lost joyous plot us year  admits fan
# Probability of anger: 0.0017760128248482943
# Probability of fear: 0.00039145592018030584
# Probability of joy: 0.9961513876914978
# Probability of neutral: 0.000630206661298871
# Probability of sadness: 0.0010509780840948224
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: case raging moody cow lol buy moody cow socks lol
# Probability of anger: 0.9943707585334778
# Probability of fear: 0.0029290984384715557
# Probability of joy: 0.0007560914382338524
# Probability of neutral: 0.0012594711733981967
# Probability of sadness: 0.0006846300675533712
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: back work  distractions
# Probability of anger: 0.01776045933365822
# Probability of fear: 0.013433272019028664
# Probability of joy: 0.01269826665520668
# Probability of neutral: 0.9544276595115662
# Probability of sadness: 0.0016803580801934004
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: prepare
# Probability of anger: 0.0855787992477417
# Probability of fear: 0.71683269739151
# Probability of joy: 0.04251984879374504
# Probability of neutral: 0.13942931592464447
# Probability of sadness: 0.015639251098036766
# Predicted Emotion: fear
# True Emotion: neutral
#
#
# Text: polished nails  ca nt find polish remover  look like yr old polished nails lol
# Probability of anger: 0.1587996929883957
# Probability of fear: 0.3060218393802643
# Probability of joy: 0.04622175544500351
# Probability of neutral: 0.1137714684009552
# Probability of sadness: 0.3751852512359619
# Predicted Emotion: sadness
# True Emotion: fear
#
#
# Text:  life shows hundred reasons cry  show hundred one reasons  smile   quotes
# Probability of anger: 0.0018428467446938157
# Probability of fear: 0.005168859846889973
# Probability of joy: 0.9904261231422424
# Probability of neutral: 0.0007123101386241615
# Probability of sadness: 0.0018498803256079555
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: know right hopefully something comes though
# Probability of anger: 0.020773880183696747
# Probability of fear: 0.05740334093570709
# Probability of joy: 0.026134207844734192
# Probability of neutral: 0.8917890191078186
# Probability of sadness: 0.0038995209615677595
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: charge  extra sending someone cable service still nt work  s robbery   cable  service
# Probability of anger: 0.11372222751379013
# Probability of fear: 0.8746415376663208
# Probability of joy: 0.004117636475712061
# Probability of neutral: 0.005651869811117649
# Probability of sadness: 0.0018667072290554643
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: london car s  degrees air con
# Probability of anger: 0.11563223600387573
# Probability of fear: 0.12345817685127258
# Probability of joy: 0.03992500901222229
# Probability of neutral: 0.689789891242981
# Probability of sadness: 0.031194666400551796
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: m also upset incorrect use comma   grammar  struggle  hesitation  backtoschool
# Probability of anger: 0.01551672164350748
# Probability of fear: 0.9155399203300476
# Probability of joy: 0.005345509387552738
# Probability of neutral: 0.01261796522885561
# Probability of sadness: 0.05097977817058563
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: tears eyes dry wo nt  m burning like wire lightbulb
# Probability of anger: 0.9934830069541931
# Probability of fear: 0.003291923552751541
# Probability of joy: 0.0009294634801335633
# Probability of neutral: 0.0016786799533292651
# Probability of sadness: 0.0006169069674797356
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: fuming
# Probability of anger: 0.9947303533554077
# Probability of fear: 0.00232706218957901
# Probability of joy: 0.000982502126134932
# Probability of neutral: 0.0014154993696138263
# Probability of sadness: 0.0005446551367640495
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: post later  comp
# Probability of anger: 0.02912645973265171
# Probability of fear: 0.04246723651885986
# Probability of joy: 0.008887792006134987
# Probability of neutral: 0.9157987833023071
# Probability of sadness: 0.0037197142373770475
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: m watching joyful noise  time cuz love movie
# Probability of anger: 0.0020400648936629295
# Probability of fear: 0.0003687487624119967
# Probability of joy: 0.9957784414291382
# Probability of neutral: 0.000928906025364995
# Probability of sadness: 0.0008839346119202673
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text:  ripkara could seen local mall school football games  im disheartened
# Probability of anger: 0.00047105332487262785
# Probability of fear: 0.0025961999781429768
# Probability of joy: 0.0008088789763860404
# Probability of neutral: 0.0021809719037264585
# Probability of sadness: 0.99394291639328
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: asks karma points please
# Probability of anger: 0.13042877614498138
# Probability of fear: 0.03676876053214073
# Probability of joy: 0.03367330878973007
# Probability of neutral: 0.768642246723175
# Probability of sadness: 0.03048686496913433
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: happens  u ok tomorrow cheer  nt give
# Probability of anger: 0.0012051394442096353
# Probability of fear: 0.0006887792842462659
# Probability of joy: 0.9966757297515869
# Probability of neutral: 0.0005087553290650249
# Probability of sadness: 0.0009215901372954249
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: always hesitate update  least s horrors iphone users endure every months
# Probability of anger: 0.001987772760912776
# Probability of fear: 0.9938158988952637
# Probability of joy: 0.0015889190835878253
# Probability of neutral: 0.0014108942123129964
# Probability of sadness: 0.0011965594021603465
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: haters taught hate shown love  good quote goes comment tiff  treat
# Probability of anger: 0.9953125715255737
# Probability of fear: 0.00185793312266469
# Probability of joy: 0.0008964773151092231
# Probability of neutral: 0.0011902343248948455
# Probability of sadness: 0.0007427016971632838
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: world facing  terrorism   terrorist s school exist  terrorist s teacher  amp  father  terrorist s motherland
# Probability of anger: 0.002295409794896841
# Probability of fear: 0.9941633343696594
# Probability of joy: 0.0012428534682840109
# Probability of neutral: 0.001143206492997706
# Probability of sadness: 0.001155214849859476
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: yeah dude  mike
# Probability of anger: 0.11832039803266525
# Probability of fear: 0.015202188864350319
# Probability of joy: 0.017628660425543785
# Probability of neutral: 0.8366413712501526
# Probability of sadness: 0.01220737211406231
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: hey turn kick  way go texans  way go   texans  noheart
# Probability of anger: 0.04662507772445679
# Probability of fear: 0.9183623194694519
# Probability of joy: 0.0188172347843647
# Probability of neutral: 0.002004081616178155
# Probability of sadness: 0.014191300608217716
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: playing september    pm  demetria taylor  blues
# Probability of anger: 0.0010246773017570376
# Probability of fear: 0.001029401202686131
# Probability of joy: 0.0009245126857422292
# Probability of neutral: 0.0019023512722924352
# Probability of sadness: 0.9951190948486328
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: past s mistakes similar terror pretty remarkable
# Probability of anger: 0.0012619096087291837
# Probability of fear: 0.9945310950279236
# Probability of joy: 0.0016626518918201327
# Probability of neutral: 0.0016446697991341352
# Probability of sadness: 0.0008997353143058717
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: middetox  wo nt eat
# Probability of anger: 0.023042527958750725
# Probability of fear: 0.058686915785074234
# Probability of joy: 0.049658000469207764
# Probability of neutral: 0.8548589944839478
# Probability of sadness: 0.013753595761954784
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: decide stop afraid  stop  free  nn  brave  free  honest  healthy  life  living  love
# Probability of anger: 0.002292322926223278
# Probability of fear: 0.9852818846702576
# Probability of joy: 0.007702633272856474
# Probability of neutral: 0.0014106862945482135
# Probability of sadness: 0.0033124203328043222
# Predicted Emotion: fear
# True Emotion: joy
#
#
# Text: ll watch  amp  wait  amp  tomorrow take anyone needs dr wo take everyone else  n s cheeks  amp  ears red hair
# Probability of anger: 0.9615676999092102
# Probability of fear: 0.008177753537893295
# Probability of joy: 0.018590694293379784
# Probability of neutral: 0.005115377251058817
# Probability of sadness: 0.006548457313328981
# Predicted Emotion: anger
# True Emotion: neutral
#
#
# Text: get paid still broke hell   shopping spree today
# Probability of anger: 0.34745532274246216
# Probability of fear: 0.032900940626859665
# Probability of joy: 0.012694675475358963
# Probability of neutral: 0.6016222238540649
# Probability of sadness: 0.005326822400093079
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: nt vcr
# Probability of anger: 0.007099575363099575
# Probability of fear: 0.018146054819226265
# Probability of joy: 0.0034823985770344734
# Probability of neutral: 0.9695815443992615
# Probability of sadness: 0.001690352102741599
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: follow friday bc needs followers
# Probability of anger: 0.03737791255116463
# Probability of fear: 0.03595975413918495
# Probability of joy: 0.010261228308081627
# Probability of neutral: 0.9099640250205994
# Probability of sadness: 0.006437125150114298
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: dream dropped iphone  broke tt  cry  iphone  nightmare
# Probability of anger: 0.0016795509727671742
# Probability of fear: 0.9929639101028442
# Probability of joy: 0.0022377297282218933
# Probability of neutral: 0.0020638005807995796
# Probability of sadness: 0.0010549877770245075
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: sense taking wrath innocent people think police shot innocent man   makeamericasafeagain
# Probability of anger: 0.9920228719711304
# Probability of fear: 0.0050714579410851
# Probability of joy: 0.0011285474756732583
# Probability of neutral: 0.001056632841937244
# Probability of sadness: 0.0007204211433418095
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text:  terrorstatepak r confirm  navazsharif post graduate distinction student university  terrorism  ca nt spare
# Probability of anger: 0.001451312331482768
# Probability of fear: 0.9948892593383789
# Probability of joy: 0.0013195956125855446
# Probability of neutral: 0.001391747733578086
# Probability of sadness: 0.0009480958105996251
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: think re good go already  nt worry
# Probability of anger: 0.0014025116106495261
# Probability of fear: 0.9930461049079895
# Probability of joy: 0.0021646672394126654
# Probability of neutral: 0.002118462696671486
# Probability of sadness: 0.001268223044462502
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: trump supporters clue meaning words used like  sad  nevertrump
# Probability of anger: 0.0022634428460150957
# Probability of fear: 0.0025087574031203985
# Probability of joy: 0.0019977805204689503
# Probability of neutral: 0.0023352978751063347
# Probability of sadness: 0.9908947944641113
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: trial result  sadness
# Probability of anger: 0.0015744019765406847
# Probability of fear: 0.0012786542065441608
# Probability of joy: 0.002881486201658845
# Probability of neutral: 0.0012518359581008554
# Probability of sadness: 0.9930136799812317
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: hard time falling sleep woke several times afraid bugs crawling ended waking bite
# Probability of anger: 0.0013519778149202466
# Probability of fear: 0.992751955986023
# Probability of joy: 0.0014056508662179112
# Probability of neutral: 0.003635122673586011
# Probability of sadness: 0.0008552891085855663
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: second
# Probability of anger: 0.047241151332855225
# Probability of fear: 0.04178069904446602
# Probability of joy: 0.01681111939251423
# Probability of neutral: 0.8908342123031616
# Probability of sadness: 0.0033328032586723566
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: doll vile creature touchline  every game tantrums  amp  shouts ref  would love see
# Probability of anger: 0.9935742020606995
# Probability of fear: 0.003297105198726058
# Probability of joy: 0.0014799227938055992
# Probability of neutral: 0.0010338725987821817
# Probability of sadness: 0.0006148924585431814
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: frown  let s distraught gardevoir  saying wishes trainer
# Probability of anger: 0.0007699971902184188
# Probability of fear: 0.004403198137879372
# Probability of joy: 0.0009301900281570852
# Probability of neutral: 0.0017672211397439241
# Probability of sadness: 0.9921294450759888
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: m surrounded trump voters  re right  fucking terrifying   redstate  despair
# Probability of anger: 0.005354002118110657
# Probability of fear: 0.9048184156417847
# Probability of joy: 0.0027851341292262077
# Probability of neutral: 0.0017139456467702985
# Probability of sadness: 0.08532851189374924
# Predicted Emotion: fear
# True Emotion: sadness
#
#
# Text: saddest part whole mess  anger  misdirected march   whitehouse
# Probability of anger: 0.9951568245887756
# Probability of fear: 0.002424724632874131
# Probability of joy: 0.0007875713054090738
# Probability of neutral: 0.0010064610978588462
# Probability of sadness: 0.0006243058014661074
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: yes indeed  know masses students would excited see  need get sorted
# Probability of anger: 0.12227480113506317
# Probability of fear: 0.7880875468254089
# Probability of joy: 0.04412158206105232
# Probability of neutral: 0.03726843744516373
# Probability of sadness: 0.008247585967183113
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: hampa hatiku
# Probability of anger: 0.005697572138160467
# Probability of fear: 0.008584056049585342
# Probability of joy: 0.008839662186801434
# Probability of neutral: 0.9738092422485352
# Probability of sadness: 0.0030695132445544004
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: np rum rage
# Probability of anger: 0.9941439032554626
# Probability of fear: 0.0032703678589314222
# Probability of joy: 0.0007639109971933067
# Probability of neutral: 0.0013289343332871795
# Probability of sadness: 0.0004929332644678652
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: rewatching glee break tears
# Probability of anger: 0.0021077741403132677
# Probability of fear: 0.0006027122144587338
# Probability of joy: 0.9959003329277039
# Probability of neutral: 0.0006893923855386674
# Probability of sadness: 0.0006997787277214229
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: great hear  s one thing makes feel like   hearty chicken noodle soup  right
# Probability of anger: 0.002327780704945326
# Probability of fear: 0.0008081651176325977
# Probability of joy: 0.9954675436019897
# Probability of neutral: 0.0006863496964797378
# Probability of sadness: 0.000710112159140408
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: us need band together apart  nevertrump promotes hatred fuels  fear
# Probability of anger: 0.002734885551035404
# Probability of fear: 0.9936070442199707
# Probability of joy: 0.0012024794705212116
# Probability of neutral: 0.0009619455086067319
# Probability of sadness: 0.0014937444357201457
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: problem right wing extremist terror groups nt given coverage  press interested
# Probability of anger: 0.001100166467949748
# Probability of fear: 0.9955796599388123
# Probability of joy: 0.0010517220944166183
# Probability of neutral: 0.0010917318286374211
# Probability of sadness: 0.001176566118374467
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: far safe staid found horribly ott times everyone seemed trying little hard
# Probability of anger: 0.22901706397533417
# Probability of fear: 0.5698084235191345
# Probability of joy: 0.01266983151435852
# Probability of neutral: 0.11910242587327957
# Probability of sadness: 0.06940221041440964
# Predicted Emotion: fear
# True Emotion: sadness
#
#
# Text: best whiney jerkass heel since heyday wcw  n  luchaunderground
# Probability of anger: 0.003993256017565727
# Probability of fear: 0.0009717498905956745
# Probability of joy: 0.9932013154029846
# Probability of neutral: 0.0004950701841153204
# Probability of sadness: 0.0013386323116719723
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: every single problem ever face solved nice blend patience optimism
# Probability of anger: 0.0012842649593949318
# Probability of fear: 0.0006108131492510438
# Probability of joy: 0.9967520236968994
# Probability of neutral: 0.000490140519104898
# Probability of sadness: 0.0008627991192042828
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: band members wanted  contact  newcastlegateshead  sunderland  musicians  musicbusiness  musicislife  music  musically  band  blues  folk
# Probability of anger: 0.0010794034460559487
# ...
# Probability of sadness: 0.0004975628107786179
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text:  azerbaijan  baku azerbaijan prevent another armenian provocation russia
# Probability of anger: 0.9922975897789001
# Probability of fear: 0.004833565559238195
# Probability of joy: 0.0009628244442865252
# Probability of neutral: 0.001278787269257009
# Probability of sadness: 0.0006272086757235229
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text:  x  x    hear   darn   optimism led    demise     li  live  zerobot
# Probability of anger: 0.0011035711504518986
# Probability of fear: 0.0005137082189321518
# Probability of joy: 0.9969122409820557
# Probability of neutral: 0.0005781800136901438
# Probability of sadness: 0.0008922258857637644
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: cross party group crofting meeting tonight suspect s going lively meeting
# Probability of anger: 0.0015164559008553624
# Probability of fear: 0.0007923587108962238
# Probability of joy: 0.9954289197921753
# Probability of neutral: 0.0015317603247240186
# Probability of sadness: 0.00073051213985309
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: ooh ve got dvd  never got around watching good
# Probability of anger: 0.03136302903294563
# Probability of fear: 0.05209585279226303
# Probability of joy: 0.0689440593123436
# Probability of neutral: 0.8394402861595154
# Probability of sadness: 0.008156826719641685
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: tati  sent emal doll  get
# Probability of anger: 0.06587015092372894
# Probability of fear: 0.08167091757059097
# Probability of joy: 0.025893790647387505
# Probability of neutral: 0.8140951991081238
# Probability of sadness: 0.012469906359910965
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: three days month two ex wives home could worse  nt know  could  oilandgas
# Probability of anger: 0.03929993510246277
# Probability of fear: 0.9349839687347412
# Probability of joy: 0.004018440842628479
# Probability of neutral: 0.0052356538362801075
# Probability of sadness: 0.01646202802658081
# Predicted Emotion: fear
# True Emotion: joy
#
#
# Text:  a   irritation isolation  lifenabler
# Probability of anger: 0.9936853051185608
# Probability of fear: 0.003012655070051551
# Probability of joy: 0.0012191442074254155
# Probability of neutral: 0.0014293879503384233
# Probability of sadness: 0.0006533751147799194
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: really offer sacrifice daily keep safe    sad
# Probability of anger: 0.001824697945266962
# Probability of fear: 0.0016811066307127476
# Probability of joy: 0.0017724396893754601
# Probability of neutral: 0.001827188883908093
# Probability of sadness: 0.9928945899009705
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: today  un armed silence  lungs rejoice freedom  insides color  woman counted  jawbone became razor  free
# Probability of anger: 0.005687227938324213
# Probability of fear: 0.001775395474396646
# Probability of joy: 0.9898239970207214
# Probability of neutral: 0.00057446607388556
# Probability of sadness: 0.002138779265806079
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: yell  bye  garbage   cheerfully
# Probability of anger: 0.0028070041444152594
# Probability of fear: 0.0009015715913847089
# Probability of joy: 0.9946836829185486
# Probability of neutral: 0.0008364178356714547
# Probability of sadness: 0.0007713587838225067
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: tired restless community  human tired asking change ignored
# Probability of anger: 0.004034350160509348
# Probability of fear: 0.9909642934799194
# Probability of joy: 0.0015762742841616273
# Probability of neutral: 0.0018964846385642886
# Probability of sadness: 0.0015286343405023217
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: m honestly upset rewarded nicole k   depressing  paulwasrobbed  rewardhardwork  bitterjury  bb
# Probability of anger: 0.3814978301525116
# Probability of fear: 0.010435725562274456
# Probability of joy: 0.006155402399599552
# Probability of neutral: 0.0027783282566815615
# Probability of sadness: 0.599132776260376
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: life changing redhead  got away
# Probability of anger: 0.7768003344535828
# Probability of fear: 0.18262283504009247
# Probability of joy: 0.014326539821922779
# Probability of neutral: 0.021884670481085777
# Probability of sadness: 0.0043656365014612675
# Predicted Emotion: anger
# True Emotion: neutral
#
#
# Text: jeans fake pockets  horrible
# Probability of anger: 0.0015679375501349568
# Probability of fear: 0.992720365524292
# Probability of joy: 0.0017083026468753815
# Probability of neutral: 0.0027930685319006443
# Probability of sadness: 0.0012104453053325415
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: hey handsome  m packing
# Probability of anger: 0.02155494876205921
# Probability of fear: 0.017100365832448006
# Probability of joy: 0.007990342564880848
# Probability of neutral: 0.9426038861274719
# Probability of sadness: 0.010750453919172287
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: maybe break smaller bits  space doesnt seem daunting
# Probability of anger: 0.00326533243060112
# Probability of fear: 0.9777690172195435
# Probability of joy: 0.0022800073493272066
# Probability of neutral: 0.00963569339364767
# Probability of sadness: 0.00704990653321147
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: cosplaying properly first time saturday  pretty nervous
# Probability of anger: 0.0011476462241262197
# Probability of fear: 0.9934428930282593
# Probability of joy: 0.0019343844614923
# Probability of neutral: 0.00219367234967649
# Probability of sadness: 0.0012813821667805314
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: re unhappy someone fucking tell re unhappy leave  nt go fuckin around people side
# Probability of anger: 0.0027739491779357195
# Probability of fear: 0.0007701285649091005
# Probability of joy: 0.003006171202287078
# Probability of neutral: 0.0014836613554507494
# Probability of sadness: 0.9919661283493042
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: cant fall asleep
# Probability of anger: 0.003976195119321346
# Probability of fear: 0.01028034184128046
# Probability of joy: 0.0023401083890348673
# Probability of neutral: 0.9809796214103699
# Probability of sadness: 0.0024237660691142082
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: seeing alex revells face gets angry
# Probability of anger: 0.9947630763053894
# Probability of fear: 0.002644373569637537
# Probability of joy: 0.0007869613473303616
# Probability of neutral: 0.0012740460224449635
# Probability of sadness: 0.0005316089373081923
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: nice  u fuming
# Probability of anger: 0.9948123693466187
# Probability of fear: 0.0023671004455536604
# Probability of joy: 0.0009100976749323308
# Probability of neutral: 0.0013961252989247441
# Probability of sadness: 0.0005142971058376133
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: unmatched party specialist co  serious  job  titles
# Probability of anger: 0.0019532348960638046
# Probability of fear: 0.0008406536071561277
# Probability of joy: 0.0010916170431300998
# Probability of neutral: 0.0036330248694866896
# Probability of sadness: 0.9924814701080322
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: ha yes look despair
# Probability of anger: 0.0007987229619175196
# Probability of fear: 0.001904921024106443
# Probability of joy: 0.0009497878490947187
# Probability of neutral: 0.0012378693791106343
# Probability of sadness: 0.9951086640357971
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: getting ready work  working weekend
# Probability of anger: 0.004305620212107897
# Probability of fear: 0.005738648120313883
# Probability of joy: 0.002153199166059494
# Probability of neutral: 0.9867607355117798
# Probability of sadness: 0.0010417206212878227
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: aside m pleasing individual m involved  pleasure comes pleasure
# Probability of anger: 0.001340259681455791
# Probability of fear: 0.0007765987538732588
# Probability of joy: 0.9962848424911499
# Probability of neutral: 0.0008362734806723893
# Probability of sadness: 0.0007619590614922345
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text:  followers  follow ll love    pouts  please
# Probability of anger: 0.0006419531418941915
# Probability of fear: 0.000991310691460967
# Probability of joy: 0.001794190495274961
# Probability of neutral: 0.0020184635650366545
# Probability of sadness: 0.9945540428161621
# Predicted Emotion: sadness
# True Emotion: neutral
#
#
# Text: true none players cops  drink chilled bitter  players walter mitty types
# Probability of anger: 0.9943300485610962
# Probability of fear: 0.003071409882977605
# Probability of joy: 0.000860174186527729
# Probability of neutral: 0.0011688704835250974
# Probability of sadness: 0.0005694468854926527
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text:
# Probability of anger: 0.006105441600084305
# Probability of fear: 0.009992409497499466
# Probability of joy: 0.006302413064986467
# Probability of neutral: 0.9757301807403564
# Probability of sadness: 0.001869591185823083
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: food gets delivered  cheering  happy
# Probability of anger: 0.001687372918240726
# Probability of fear: 0.0005990025820210576
# Probability of joy: 0.9963028430938721
# Probability of neutral: 0.0006333936471492052
# Probability of sadness: 0.0007772878161631525
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: medhurst play
# Probability of anger: 0.05560475215315819
# Probability of fear: 0.15908797085285187
# Probability of joy: 0.2780981659889221
# Probability of neutral: 0.2530030906200409
# Probability of sadness: 0.25420597195625305
# Predicted Emotion: joy
# True Emotion: neutral
#
#
# Text: dont feel grateful grateful  written  things work together good  love god
# Probability of anger: 0.04598370939493179
# Probability of fear: 0.037553563714027405
# Probability of joy: 0.7837172150611877
# Probability of neutral: 0.019620131701231003
# Probability of sadness: 0.11312544345855713
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text:  court
# Probability of anger: 0.02237236686050892
# Probability of fear: 0.03692583367228508
# Probability of joy: 0.009251952171325684
# Probability of neutral: 0.9233930706977844
# Probability of sadness: 0.008056719787418842
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: memphis looking bright  rojo looking like rojo
# Probability of anger: 0.0022478194441646338
# Probability of fear: 0.0006392415962181985
# Probability of joy: 0.9938457608222961
# Probability of neutral: 0.001612361054867506
# Probability of sadness: 0.0016549031715840101
# Predicted Emotion: joy
# True Emotion: joy
#
#
# Text: way work
# Probability of anger: 0.004319458734244108
# Probability of fear: 0.0052960882894694805
# Probability of joy: 0.0022060556802898645
# Probability of neutral: 0.9868378043174744
# Probability of sadness: 0.0013406561920419335
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: know  nt want left home weekend
# Probability of anger: 0.00812093261629343
# Probability of fear: 0.009378762915730476
# Probability of joy: 0.0023257476277649403
# Probability of neutral: 0.9774102568626404
# Probability of sadness: 0.002764209872111678
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text: hate ideas afraid share
# Probability of anger: 0.000785755692049861
# Probability of fear: 0.9950280785560608
# Probability of joy: 0.00090886460384354
# Probability of neutral: 0.0017134899972006679
# Probability of sadness: 0.0015638872282579541
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: sorry main twitter im depress
# Probability of anger: 0.000596606929320842
# Probability of fear: 0.0013994622277095914
# Probability of joy: 0.0007398315938189626
# Probability of neutral: 0.0017530621262267232
# Probability of sadness: 0.9955110549926758
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: evidently feels  norms  show  tax return  nothing
# Probability of anger: 0.08382637798786163
# Probability of fear: 0.13914623856544495
# Probability of joy: 0.015932025387883186
# Probability of neutral: 0.5835456848144531
# Probability of sadness: 0.17754971981048584
# Predicted Emotion: neutral
# True Emotion: fear
#
#
# Text: m  nervous test rip
# Probability of anger: 0.0012210740242153406
# Probability of fear: 0.9922175407409668
# Probability of joy: 0.0018796701915562153
# Probability of neutral: 0.00366955460049212
# Probability of sadness: 0.001012206426821649
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: walk darkness despondency  scverses ve memorized shine light heart  ex  lam
# Probability of anger: 0.002285705879330635
# Probability of fear: 0.0010534876491874456
# Probability of joy: 0.001266878447495401
# Probability of neutral: 0.001087258686311543
# Probability of sadness: 0.9943066239356995
# Predicted Emotion: sadness
# True Emotion: fear
#
#
# Text: bad news fam  life still hard awful  depression  atleastihavebuffy
# Probability of anger: 0.003440976608544588
# Probability of fear: 0.02779354155063629
# Probability of joy: 0.002244925359264016
# Probability of neutral: 0.0012207194231450558
# Probability of sadness: 0.9652998447418213
# Predicted Emotion: sadness
# True Emotion: fear
#
#
# Text: actual nightmare
# Probability of anger: 0.002003221772611141
# Probability of fear: 0.9923943281173706
# Probability of joy: 0.0022319129202514887
# Probability of neutral: 0.0023518505040556192
# Probability of sadness: 0.0010187237057834864
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text:  days  never fucking pen      nffc  bitter
# Probability of anger: 0.9950331449508667
# Probability of fear: 0.0021100668236613274
# Probability of joy: 0.0010113490279763937
# Probability of neutral: 0.0012909305514767766
# Probability of sadness: 0.0005545520689338446
# Predicted Emotion: anger
# True Emotion: anger
#
#
# Text: s worst affliction someone know ever convinced
# Probability of anger: 0.001093727769330144
# Probability of fear: 0.0008890281314961612
# Probability of joy: 0.0012432060902938247
# Probability of neutral: 0.00138641067314893
# Probability of sadness: 0.995387613773346
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: gah forgot separate bins  maybe bad idea
# Probability of anger: 0.025204434990882874
# Probability of fear: 0.00808811467140913
# Probability of joy: 0.005117332562804222
# Probability of neutral: 0.9569650292396545
# Probability of sadness: 0.004625129513442516
# Predicted Emotion: neutral
# True Emotion: neutral
#
#
# Text:  india right reply  unga   pakistan preaching human rights country global epicentre
# Probability of anger: 0.5460767149925232
# Probability of fear: 0.2784731388092041
# Probability of joy: 0.09963162243366241
# Probability of neutral: 0.014808314852416515
# Probability of sadness: 0.06101030483841896
# Predicted Emotion: anger
# True Emotion: fear
#
#
# Text: this sadly history teacher talked fuck remember
# Probability of anger: 0.0008768896223045886
# Probability of fear: 0.003145369701087475
# Probability of joy: 0.0011603330494835973
# Probability of neutral: 0.001069784164428711
# Probability of sadness: 0.9937475919723511
# Predicted Emotion: sadness
# True Emotion: sadness
#
#
# Text: pumped interview  nervous
# Probability of anger: 0.0011986142490059137
# Probability of fear: 0.9937520623207092
# Probability of joy: 0.0016090041026473045
# Probability of neutral: 0.0021983198821544647
# Probability of sadness: 0.0012419786071404815
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: follow amazing australian author  fiction  horror  zombies  angels  demons  vampires  werewolves  follow  authorlove
# Probability of anger: 0.0019946678075939417
# Probability of fear: 0.9937171936035156
# Probability of joy: 0.0016273995861411095
# Probability of neutral: 0.0012985821813344955
# Probability of sadness: 0.0013622171245515347
# Predicted Emotion: fear
# True Emotion: fear
#
#
# Text: please tell us protesting  injustice requires  burning  beating  looting terrible optics  toussaintromain true leader
# Probability of anger: 0.9940255880355835
# Probability of fear: 0.00353381410241127
# Probability of joy: 0.0007829756359569728
# Probability of neutral: 0.000920554215554148
# Probability of sadness: 0.000736942165531218
# Predicted Emotion: anger
# True Emotion: anger

# %%
text_to_predict = "Feeling a bit anxious about the presentation"

tokenized_text = tokenizer(text_to_predict, truncation=True, padding=True, return_tensors='pt', max_length=512)

with torch.no_grad():
    outputs = bert_model(**tokenized_text)
    logits = outputs.logits

    probabilities = softmax(logits, dim=1)

probabilities_np = probabilities.cpu().numpy()
predicted_label_np = torch.argmax(probabilities, dim=1).cpu().numpy()

print(f"Text: {text_to_predict}")
for j, emotion in enumerate(label_encoder.classes_):
    print(f"Probability of {emotion}: {probabilities_np[0, j]}")
print("Predicted Emotion:", label_encoder.classes_[predicted_label_np[0]])
# Out:
# Text: Feeling a bit anxious about the presentation
# Probability of anger: 0.023017041385173798
# Probability of fear: 0.4965920150279999
# Probability of joy: 0.01633150316774845
# Probability of neutral: 0.46078336238861084
# Probability of sadness: 0.0032760321628302336
# Predicted Emotion: fear

# %%
emotions = [
    "I hate getting up, it's so annoying.",
    "I love cats and their sweet noses.",
    "I put up with my schoolmates.",
    "This movie made me feel so happy!",
    "The traffic jam today was frustrating.",
    "Spending time with friends always brings joy.",
    "I feel lonely when I'm alone at home.",
    "Excited about the upcoming vacation!",
    "I love spending time with friends and family. It brings me so much joy!",
    "The rude behavior of that person made me really angry.",
    "I'm feeling neutral about the upcoming changes at work.",
    "Today is just another neutral day for me.",
    "The constant delays and issues with the project are making me angry.",
    "Winning the lottery would bring me immense joy and happiness!",
    "I don't have a strong opinion on the matter; I'm feeling quite neutral.",
    "The news about the recent event left me in deep sadness.",
    "Losing a loved one is an experience filled with sadness and grief.",
    "I have a neutral stance on the current political situation.",
    "I'm so happy right now!", "This is really frustrating."
    "Feeling sad and lonely tonight.",
    "I can't contain my excitement!",
    "Angry about the recent events.",
    "Today is a wonderful day!",
    "Dealing with a lot of stress.",
    "The movie made me cry, but it was beautiful.",
    "I'm thrilled about the upcoming project.",
    "Feeling a bit anxious about the presentation."
    "I'm afraid of spiders, they're so big!"
]

for text in emotions:
    tokenized_text = tokenizer(text, truncation=True, padding=True, return_tensors='pt', max_length=512)

    tokenized_text = {key: val.to(device) for key, val in tokenized_text.items()}

    outputs = bert_model(**tokenized_text)

    logits = outputs.logits
    probabilities = softmax(logits, dim=1)

    predicted_label = torch.argmax(probabilities).item()
    decoded_emotion = label_encoder.classes_[predicted_label]

    print(f"'{text}' : {decoded_emotion}")

# %%
texts = []
predicted_emotions = []

for text in emotions:
    tokenized_text = tokenizer(text, truncation=True, padding=True, return_tensors='pt', max_length=512)

    tokenized_text = {key: val.to(device) for key, val in tokenized_text.items()}

    outputs = bert_model(**tokenized_text)

    logits = outputs.logits
    probabilities = softmax(logits, dim=1)

    predicted_label = torch.argmax(probabilities).item()
    decoded_emotion = label_encoder.classes_[predicted_label]

    texts.append(text)
    predicted_emotions.append(decoded_emotion)

emotion_df = pd.DataFrame({'Text': texts, 'Predicted Emotion': predicted_emotions})

print(emotion_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 texts = []
#       2 predicted_emotions = []
# ----> 4 for text in emotions:
#       5     tokenized_text = tokenizer(text, truncation=True, padding=True, return_tensors='pt', max_length=512)
#       7     tokenized_text = {key: val.to(device) for key, val in tokenized_text.items()}
#
# NameError: name 'emotions' is not defined

# %%
model_save_path = "bert_model"

bert_model.save_pretrained(model_save_path)

# %%
save_path = "bert_model2"

bert_model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)
# Out:
# ('bert_model2\\tokenizer_config.json',
#  'bert_model2\\special_tokens_map.json',
#  'bert_model2\\vocab.txt',
#  'bert_model2\\added_tokens.json')

# %%
from transformers import BertTokenizer, BertForSequenceClassification

model_load_path = "bert_model2"

loaded_bert_model = BertForSequenceClassification.from_pretrained(model_load_path)
loaded_tokenizer = BertTokenizer.from_pretrained(model_load_path)

# %%
from torch.nn.functional import softmax
import torch

text_to_predict = "Today is a wonderful excitement day!"

tokenized_text = tokenizer(text_to_predict, truncation=True, padding=True, return_tensors='pt', max_length=512)

with torch.no_grad():
    outputs = loaded_bert_model(**tokenized_text)

    logits = outputs.logits

    probabilities = softmax(logits, dim=1)

probabilities_np = probabilities.cpu().numpy()

print(f"Text: {text_to_predict}")
for j, emotion in enumerate(label_encoder.classes_):
    print(f"Probability of {emotion}: {probabilities_np[0, j]}")
print("Predicted Emotion:", label_encoder.classes_[torch.argmax(probabilities, dim=1).item()])
# Out:
# Text: Today is a wonderful excitement day!
# Probability of anger: 0.003633469808846712
# Probability of fear: 0.008612258359789848
# Probability of joy: 0.9843831658363342
# Probability of neutral: 0.0027442765422165394
# Probability of sadness: 0.0006268497090786695
# Predicted Emotion: joy

# %%
from torch.nn.functional import softmax
import torch

text_to_predict = "I'm afraid of spiders, they're so big!"

tokenized_text = tokenizer(text_to_predict, truncation=True, padding=True, return_tensors='pt', max_length=512)

with torch.no_grad():
    outputs = loaded_bert_model(**tokenized_text)

    logits = outputs.logits

    probabilities = softmax(logits, dim=1)

probabilities_np = probabilities.cpu().numpy()

print(f"Text: {text_to_predict}")
for j, emotion in enumerate(label_encoder.classes_):
    print(f"Probability of {emotion}: {probabilities_np[0, j]}")
print("Predicted Emotion:", label_encoder.classes_[torch.argmax(probabilities, dim=1).item()])
# Out:
# Text: I'm afraid of spiders, they're so big!
# Probability of anger: 0.010529370978474617
# Probability of fear: 0.9822942018508911
# Probability of joy: 0.0015460399445146322
# Probability of neutral: 0.004858497530221939
# Probability of sadness: 0.000771855004131794
# Predicted Emotion: fear

# %%
emotions = [
    "I hate getting up, it's so annoying.",
    "I love cats and their sweet noses.",
    "I put up with my schoolmates.",
    "This movie made me feel so happy!",
    "The traffic jam today was frustrating.",
    "Spending time with friends always brings joy.",
    "I feel lonely when I'm alone at home.",
    "Excited about the upcoming vacation!",
    "I love spending time with friends and family. It brings me so much joy!",
    "The rude behavior of that person made me really angry.",
    "I'm feeling neutral about the upcoming changes at work.",
    "Today is just another neutral day for me.",
    "The constant delays and issues with the project are making me angry.",
    "Winning the lottery would bring me immense joy and happiness!",
    "I don't have a strong opinion on the matter; I'm feeling quite neutral.",
    "The news about the recent event left me in deep sadness.",
    "Losing a loved one is an experience filled with sadness and grief.",
    "I have a neutral stance on the current political situation.",
    "I'm so happy right now!", "This is really frustrating."
    "Feeling sad and lonely tonight.",
    "I can't contain my excitement!",
    "Angry about the recent events.",
    "Today is a wonderful day!",
    "Dealing with a lot of stress.",
    "The movie made me cry, but it was beautiful.",
    "I'm thrilled about the upcoming project.",
    "Feeling a bit anxious about the presentation."
    "I'm afraid of spiders, they're so big!"
]

texts = []
predicted_emotions = []
probabilities = []

for text in emotions:
    tokenized_text = tokenizer(text, truncation=True, padding=True, return_tensors='pt', max_length=512)

    tokenized_text = {key: val.to(device) for key, val in tokenized_text.items()}

    with torch.no_grad():
        outputs = loaded_bert_model(**tokenized_text)

    logits = outputs.logits
    probabilities_tensor = softmax(logits, dim=1)

    predicted_label = torch.argmax(probabilities_tensor).item()
    decoded_emotion = label_encoder.classes_[predicted_label]
    probability = probabilities_tensor[0, predicted_label].item()  # Probability of the predicted class

    texts.append(text)
    predicted_emotions.append(decoded_emotion)
    probabilities.append(probability)

emotion_df = pd.DataFrame({'Text': texts, 'Predicted Emotion': predicted_emotions, 'Probability': probabilities})
emotion_df
# Out:
#                                                  Text Predicted Emotion  \
# 0                I hate getting up, it's so annoying.           neutral
# 1                  I love cats and their sweet noses.               joy
# 2                       I put up with my schoolmates.           neutral
# 3                   This movie made me feel so happy!               joy
# 4              The traffic jam today was frustrating.           neutral
# 5       Spending time with friends always brings joy.               joy
# 6               I feel lonely when I'm alone at home.           neutral
# 7                Excited about the upcoming vacation!             anger
# 8   I love spending time with friends and family. ...               joy
# 9   The rude behavior of that person made me reall...             anger
# 10  I'm feeling neutral about the upcoming changes...           sadness
# 11          Today is just another neutral day for me.           sadness
# 12  The constant delays and issues with the projec...             anger
# 13  Winning the lottery would bring me immense joy...               joy
# 14  I don't have a strong opinion on the matter; I...           sadness
# 15  The news about the recent event left me in dee...           sadness
# 16  Losing a loved one is an experience filled wit...           sadness
# 17  I have a neutral stance on the current politic...           sadness
# 18                            I'm so happy right now!               joy
# 19  This is really frustrating.Feeling sad and lon...           sadness
# 20                     I can't contain my excitement!               joy
# 21                     Angry about the recent events.             anger
# 22                          Today is a wonderful day!               joy
# 23                      Dealing with a lot of stress.           neutral
# 24       The movie made me cry, but it was beautiful.           neutral
# 25           I'm thrilled about the upcoming project.               joy
# 26  Feeling a bit anxious about the presentation.I...              fear
#
#     Probability
# 0      0.663908
# 1      0.936388
# 2      0.753806
# 3      0.994885
# 4      0.659740
# 5      0.995771
# 6      0.872889
# 7      0.297468
# 8      0.995701
# 9      0.994666
# 10     0.483747
# 11     0.659920
# 12     0.995311
# 13     0.995646
# 14     0.838188
# 15     0.994238
# 16     0.993682
# 17     0.648506
# 18     0.992521
# 19     0.728212
# 20     0.966113
# 21     0.995553
# 22     0.981977
# 23     0.952815
# 24     0.706434
# 25     0.968004
# 26     0.983929
