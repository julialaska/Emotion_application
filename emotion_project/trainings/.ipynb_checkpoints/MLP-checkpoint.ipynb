# %%
import re
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
from nltk import PorterStemmer, word_tokenize
from nltk.corpus import stopwords
import unidecode
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier
import joblib

# %%
train_data = pd.read_csv('data/wassa_train.csv')
test_data = pd.read_csv('data/wassa_test.csv')
val_data = pd.read_csv('data/wassa_val.csv')

# %%
train_data
# Out:
#         id                                              tweet  emotion
# 0     1929  Kinda wished I watched mischievous kiss before...      joy
# 1     4049  When you forget to mention you were bought dre...    anger
# 2     5405  @FreyaLynn @donniewahlberg yep! jimmy buffett ...  neutral
# 3     5900  @philcampbell blue skies? where, it's still gr...  neutral
# 4     3712  Some moving clips on youtube tonight of the vi...    anger
# ...    ...                                                ...      ...
# 5996  5407  @koifusionpdx i was so close to the tacos...on...  neutral
# 5997   496  @Fatumoriginal there's no sitcom better! If u ...  sadness
# 5998   499  @Mysteri759 @Ren102e906 @slb42jcb @swoozyqyah ...  sadness
# 5999  1784  Watch this amazing live.ly broadcast by @ittzd...      joy
# 6000  4829            @daniellemhicks lol what!! where is it!  neutral
#
# [6001 rows x 3 columns]

# %%
def preprocess_text(text):
    result = text.lower()
    result = result.strip()
    result = re.result = re.sub(r"http\S+", "", result)
    result = re.sub('\S*@\S*\s?', '', result)
    result = unidecode.unidecode(result)
    stop_words = stopwords.words("english")
    word_list = word_tokenize(result)

    stemmed_sentence = ""
    for word in word_list:
        if word not in stop_words:
            stemmed_sentence += word
            stemmed_sentence += " "

    result = stemmed_sentence
    whitelist = set('abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ')
    result = ''.join(filter(whitelist.__contains__, result))
    result = ''.join([i for i in result if not i.isdigit()])
    return result

# %%
def preprocess_text_list(text_list):
  for i,text in enumerate(text_list):
    text_list[i] = preprocess_text(text_list[i])

# %%
train_texts = train_data["tweet"].tolist()
val_texts = val_data["tweet"].tolist()
test_texts = test_data["tweet"].tolist()


train_labels = train_data["emotion"].tolist()
val_labels = val_data["emotion"].tolist()
test_labels = test_data["emotion"].tolist()

train_labels[:10]
# Out:
# ['joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral']

# %%
preprocess_text_list(train_texts)
preprocess_text_list(val_texts)
preprocess_text_list(test_texts)

train_texts[:10]
# Out:
# ['kinda wished watched mischievous kiss playful kiss ',
#  'forget mention bought dreamboys tickets ',
#  'yep  jimmy buffett ftw     jimmy needs tweet words wisdom every morning ',
#  'blue skies   s still grey hazy window ',
#  'moving clips youtube tonight vigil held tulsa metropolitan baptist church  terencecruther  justice  sadness ',
#  'makes successful  happy forever ',
#  'morning hon  breakfast  cant decide ',
#  'standard candice starting show pout  startasyoumeantogoon  gbbo ',
#  '   would frown bit  folding arms  why every time m need assistance someone expects lil   ',
#  'someone make cofffeeeeeee  ']

# %%
 vectorizer = TfidfVectorizer()
 vectorizer.fit(train_texts)
# Out:
# TfidfVectorizer()

# %%
vectorized_train_texts = vectorizer.transform(train_texts)
vectorized_val_texts = vectorizer.transform(val_texts)
vectorized_test_texts = vectorizer.transform(test_texts)

# %%
label_encoder = LabelEncoder()
encoded_train_labels = label_encoder.fit_transform(train_labels)
encoded_val_labels = label_encoder.transform(val_labels)
encoded_test_labels = label_encoder.transform(test_labels)

# %%
mlp_model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, activation='relu', solver='adam', random_state=42)
mlp_model.fit(vectorized_train_texts, encoded_train_labels)
# Out:
# MLPClassifier(max_iter=300, random_state=42)

# %%
y_pred = mlp_model.predict_proba(vectorized_test_texts)
y_pred
# Out:
# array([[3.05445346e-07, 1.02690574e-06, 8.05369170e-07, 1.82345827e-06,
#         9.99996039e-01],
#        [9.71791293e-01, 1.11290332e-03, 4.07191813e-05, 2.66940322e-02,
#         3.61052323e-04],
#        [1.16510914e-02, 3.65246494e-02, 5.32468685e-04, 9.50738313e-01,
#         5.53477931e-04],
#        ...,
#        [1.93770608e-06, 9.99994279e-01, 4.03483905e-07, 2.78092325e-06,
#         5.98530430e-07],
#        [5.59203362e-05, 9.99835854e-01, 2.42315261e-05, 6.76086374e-05,
#         1.63853493e-05],
#        [3.33323311e-01, 6.65484845e-01, 2.21058536e-04, 2.52349830e-04,
#         7.18435675e-04]])

# %%
predicted_emotions = label_encoder.inverse_transform(y_pred.argmax(axis=1))
probabilities = y_pred.max(axis=1)

# %%
for text, emotion, prob in zip(test_texts, predicted_emotions, probabilities):
    print(f"Text: {text}\nPredicted Emotion: {emotion} (Probability: {prob:.2f})\n")
# Out:
# Text:  depression
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: peanut butter takes away sting
# Predicted Emotion: anger (Probability: 0.97)
#
# Text: mannnn  got iphone    im jealous
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: speech bold coz nt written pm ns bt expressiontone dull n dim
# Predicted Emotion: sadness (Probability: 0.79)
#
# Text: fair
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: may send copy  herothegreyhound  either ebook real paper one  boy greyhound  smiles  tears  laughter
# Predicted Emotion: joy (Probability: 0.94)
#
# Text: baby going first sleepover tonight m gon na need lot wine get today
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: stayed home
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: tomorrowland central nt gotten confirmation m signed star tours  waiting see give shift
# Predicted Emotion: fear (Probability: 0.72)
#
# Text: guy video m shaking
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: cancelling home fibe  internet tv afternoon  soon arrange alternate internet    angry  fedup
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: literally guy  somewouldsaysuccessful guy  tell this ship sail  kay guy  first  re working sub  last  sunk
# Predicted Emotion: sadness (Probability: 0.39)
#
# Text: feels like lost best friend  lost  fml  missingyou
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: dream dropped iphone  broke tt  cry  iphone
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text:  serious  fredsirieix lives peckham  south london s  love guru  big
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: pregame nerves settled  l  cheering home guys  aflcatsswans  proudlysydney  goswans
# Predicted Emotion: fear (Probability: 0.49)
#
# Text: life s short frowning long
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: high school remember helping neighbors clean back home greenville  pretty sobering stuff   sadness
# Predicted Emotion: neutral (Probability: 0.83)
#
# Text: cutting hair allll day wish outside
# Predicted Emotion: fear (Probability: 0.86)
#
# Text: accept challenges literally even feel exhilaration victory    george s patton
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: recommended reading  prisoners hate aaron beck
# Predicted Emotion: anger (Probability: 0.94)
#
# Text:  peoplelikemebecause unknown reason try discourage
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: m trying lots pain though
# Predicted Emotion: neutral (Probability: 0.77)
#
# Text: really want go fright night really nt
# Predicted Emotion: fear (Probability: 0.97)
#
# Text: cnt get   goin ur old messages     gt   gt   gt   gt  help   lt   lt   lt   lt
# Predicted Emotion: fear (Probability: 0.50)
#
# Text: anyone know good png compression tool os x  tried pngcrush doesnt run
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: hey way u make somatic theme leopard  themes installers already shapeshifter independent
# Predicted Emotion: neutral (Probability: 0.62)
#
# Text: little frustrates much misplacing something  looking keys  hours
# Predicted Emotion: anger (Probability: 0.56)
#
# Text: perfect illusion  least know   angry  ladygaga  iscalming  mysoul
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: m type flee adversity discourage  ll always stand strong paint
# Predicted Emotion: sadness (Probability: 0.93)
#
# Text: sav tells mom  love  responds oh    sad
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: favourite joyful soul
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: lot positives tonight  clean sheet  payet got free kick practice  zaza looked lively made lot good runs
# Predicted Emotion: joy (Probability: 0.96)
#
# Text: tom phillips jovial start week s show joe strutting video package quite juxtaposition
# Predicted Emotion: joy (Probability: 0.77)
#
# Text: sorry  offend u griffin
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: majority people irritate fuck  cba people ahahah
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: sucks  old actually
# Predicted Emotion: anger (Probability: 0.73)
#
# Text: massive argument alarm today  nt want get  nt know re going fix tomorrow morning
# Predicted Emotion: neutral (Probability: 0.58)
#
# Text: oh noes  hey  s tatoo say
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: sick doctors waiting room
# Predicted Emotion: joy (Probability: 0.31)
#
# Text: r u scared present front class  severe anxiety  whats r u sad sometimes   go get ur depression checked imediately
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: want monte cristo sandwich sooo  bad
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: got paid vacuum rat poop     never dull day biology department
# Predicted Emotion: sadness (Probability: 0.74)
#
# Text: really want read fic found s  serious room full  memes
# Predicted Emotion: sadness (Probability: 0.96)
#
# Text: assured eventual destruction would  interests public  cheerfully accept   sherlock holmes
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: u wen ur love cheats u  wen thy nt understand emotions behind anger  constant waiting  u
# Predicted Emotion: sadness (Probability: 0.57)
#
# Text: seriously need pop curtains matt filming scare bejesus
# Predicted Emotion: fear (Probability: 0.99)
#
# Text:  one person ruins season   angry
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: watch amazing lively broadcast  musically
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: says maw day  wan na day sober october way  says ave mer chance movember son   classicmoira  glasgow  sober
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: ve whole time watching ve lost  glasses   hilarious
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: dread think
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: fucker blocked  years ago question lol  proper holds grudge old joe
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: looking forward div  next year  revenge  leictershireaway  therey
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: world drives whoever assessed tenderhearted vulnerable build guards  amp  invigorate raging self defense mechanisms
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: m back elated record fucking shit studio evening
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: momma irritate asking questions like gone
# Predicted Emotion: anger (Probability: 0.88)
#
# Text: anyone drinks sparkling water demon
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: s political map relentless pursuit power
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: easy ride child cries  noh  find  find  nothing  nwe sullen misty moor
# Predicted Emotion: fear (Probability: 0.70)
#
# Text: s exactly rabid tub thumper compared mcternan
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: aww wish sun  get tan      walks  go meee go meeee
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: hes right civil war starts wall wall terrorism nt fancy muzzy s chances
# Predicted Emotion: fear (Probability: 0.92)
#
# Text: nt know heck space time bgt bored
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: transparency openness  dull sell fans group  want verbs like buying  defending  building securing
# Predicted Emotion: sadness (Probability: 0.95)
#
# Text: watching rain
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: re cheerfully defending group unchecked  armed thugs ve shown history racism  violence  lies
# Predicted Emotion: fear (Probability: 0.89)
#
# Text:  india  afraid  bad  terrorism
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: would like know source president s optimism running country  wonder answer curiosity
# Predicted Emotion: fear (Probability: 0.95)
#
# Text: may  alwayshungry nt sunk low yet
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: carry wayward son ll peace done lay weary head rest nt cry
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: something needs done people hogging machines  nobody use  machines one time   notfair  whypay
# Predicted Emotion: anger (Probability: 0.95)
#
# Text: little girl still holding phone tears pouring eyes
# Predicted Emotion: sadness (Probability: 0.79)
#
# Text: tend s going get infections  nnhe s frowning looking  nit must hurt damn
# Predicted Emotion: sadness (Probability: 0.76)
#
# Text: finally started  homefronttherevolution  story gameplay     terrible  wasteofmoney
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: taking picture   awkward smile  nme picture day   awkward smile  nconclusion  stop smiling    n  pictureday  ornot
# Predicted Emotion: joy (Probability: 1.00)
#
# Text:   politicallycorrect  bs  offended assumption usa change visitor   amp  nt like
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: funeral  close casket  want play  call recording completed    lost  podcasting  talkshoe
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: hangover
# Predicted Emotion: neutral (Probability: 0.94)
#
# Text: theyve substituted hood badge gun   public opinion indictment charlotte police   dark  sadtimes  america  race
# Predicted Emotion: anger (Probability: 0.49)
#
# Text: heart left long againnn  slight pout turned smile  nnheheh kidding  m fine
# Predicted Emotion: sadness (Probability: 0.94)
#
# Text: yes  amp  cheering homecoming game
# Predicted Emotion: joy (Probability: 0.82)
#
# Text: bad temperament  hissyfits
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text:  smile mean thousand words  also hide thousand  problems   fact  teamfollowback
# Predicted Emotion: joy (Probability: 0.28)
#
# Text: m way busy tired time worry past things regretting  never
# Predicted Emotion: fear (Probability: 0.81)
#
# Text: come bell  ring  want go outside
# Predicted Emotion: neutral (Probability: 0.96)
#
# Text: thought funny   maybe coincidence  green must official color optimism
# Predicted Emotion: joy (Probability: 0.93)
#
# Text: want starbucks
# Predicted Emotion: neutral (Probability: 0.67)
#
# Text: may suggest  meal made beans  onions  amp  garlic  day class   revenge
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: ca nt feel weekend fever anymore everyday day
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: s first expac since wrath feels like proper evolution  game
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: work today  went shopping  relaxing  amp  learning toefl
# Predicted Emotion: neutral (Probability: 0.96)
#
# Text:  people country  million  going ruin whole country  people
# Predicted Emotion: fear (Probability: 0.97)
#
# Text: prepurchased tickets sent soon  coming saturday evening show  tickets show   panic  hoys
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: s brilliant  lost joyous plot us year  admits fan
# Predicted Emotion: sadness (Probability: 0.78)
#
# Text: case raging moody cow lol buy moody cow socks lol
# Predicted Emotion: anger (Probability: 0.57)
#
# Text: back work  distractions
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: prepare
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: polished nails  ca nt find polish remover  look like yr old polished nails lol
# Predicted Emotion: fear (Probability: 0.91)
#
# Text:  life shows hundred reasons cry  show hundred one reasons  smile   quotes
# Predicted Emotion: joy (Probability: 0.80)
#
# Text: know right hopefully something comes though
# Predicted Emotion: joy (Probability: 0.47)
#
# Text: charge  extra sending someone cable service still nt work  s robbery   cable  service
# Predicted Emotion: fear (Probability: 0.94)
#
# Text: london car s  degrees air con
# Predicted Emotion: neutral (Probability: 0.88)
#
# Text: m also upset incorrect use comma   grammar  struggle  hesitation  backtoschool
# Predicted Emotion: fear (Probability: 0.82)
#
# Text: tears eyes dry wo nt  m burning like wire lightbulb
# Predicted Emotion: anger (Probability: 0.93)
#
# Text: fuming
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: post later  comp
# Predicted Emotion: neutral (Probability: 0.90)
#
# Text: m watching joyful noise  time cuz love movie
# Predicted Emotion: joy (Probability: 1.00)
#
# Text:  ripkara could seen local mall school football games  im disheartened
# Predicted Emotion: sadness (Probability: 0.96)
#
# Text: asks karma points please
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: happens  u ok tomorrow cheer  nt give
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: always hesitate update  least s horrors iphone users endure every months
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: haters taught hate shown love  good quote goes comment tiff  treat
# Predicted Emotion: joy (Probability: 0.46)
#
# Text: world facing  terrorism   terrorist s school exist  terrorist s teacher  amp  father  terrorist s motherland
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: yeah dude  mike
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: hey turn kick  way go texans  way go   texans  noheart
# Predicted Emotion: fear (Probability: 0.96)
#
# Text: playing september    pm  demetria taylor  blues
# Predicted Emotion: sadness (Probability: 0.98)
#
# Text: past s mistakes similar terror pretty remarkable
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: middetox  wo nt eat
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: decide stop afraid  stop  free  nn  brave  free  honest  healthy  life  living  love
# Predicted Emotion: fear (Probability: 0.68)
#
# Text: ll watch  amp  wait  amp  tomorrow take anyone needs dr wo take everyone else  n s cheeks  amp  ears red hair
# Predicted Emotion: fear (Probability: 0.61)
#
# Text: get paid still broke hell   shopping spree today
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: nt vcr
# Predicted Emotion: sadness (Probability: 0.49)
#
# Text: follow friday bc needs followers
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: dream dropped iphone  broke tt  cry  iphone  nightmare
# Predicted Emotion: fear (Probability: 0.62)
#
# Text: sense taking wrath innocent people think police shot innocent man   makeamericasafeagain
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  terrorstatepak r confirm  navazsharif post graduate distinction student university  terrorism  ca nt spare
# Predicted Emotion: fear (Probability: 0.73)
#
# Text: think re good go already  nt worry
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: trump supporters clue meaning words used like  sad  nevertrump
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: trial result  sadness
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: hard time falling sleep woke several times afraid bugs crawling ended waking bite
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: second
# Predicted Emotion: anger (Probability: 0.60)
#
# Text: doll vile creature touchline  every game tantrums  amp  shouts ref  would love see
# Predicted Emotion: anger (Probability: 0.90)
#
# Text: frown  let s distraught gardevoir  saying wishes trainer
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: m surrounded trump voters  re right  fucking terrifying   redstate  despair
# Predicted Emotion: fear (Probability: 0.63)
#
# Text: saddest part whole mess  anger  misdirected march   whitehouse
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: yes indeed  know masses students would excited see  need get sorted
# Predicted Emotion: fear (Probability: 0.73)
#
# Text: hampa hatiku
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: np rum rage
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: rewatching glee break tears
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: great hear  s one thing makes feel like   hearty chicken noodle soup  right
# Predicted Emotion: joy (Probability: 0.94)
#
# Text: us need band together apart  nevertrump promotes hatred fuels  fear
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: problem right wing extremist terror groups nt given coverage  press interested
# Predicted Emotion: fear (Probability: 0.99)
#
# Text: far safe staid found horribly ott times everyone seemed trying little hard
# Predicted Emotion: sadness (Probability: 0.53)
#
# Text: best whiney jerkass heel since heyday wcw  n  luchaunderground
# Predicted Emotion: joy (Probability: 0.69)
#
# Text: every single problem ever face solved nice blend patience optimism
# Predicted Emotion: joy (Probability: 0.96)
#
# Text: band members wanted  contact  newcastlegateshead  sunderland  musicians  musicbusiness  musicislife  music  musically  band  blues  folk
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: panic attack call real fan makes mad like dont even words explain  people give
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: trust know appreciate willingness explain details  attempt levity
# Predicted Emotion: joy (Probability: 0.98)
#
# Text: lost wallet  found  lost found      ncollege brazy
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: maybe transgender media would cover
# Predicted Emotion: anger (Probability: 0.53)
#
# Text: joking  nt parents   dark
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: fact levity  movie theaters post actually play na served  best part movies like thehulk
# Predicted Emotion: fear (Probability: 0.59)
#
# Text: jus spoke  lawyer  blow trial to
# Predicted Emotion: neutral (Probability: 0.93)
#
# Text: m cheery
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: even ie would better
# Predicted Emotion: fear (Probability: 0.64)
#
# Text: could never angry drunk lol yall weirdos enjoy time
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: lost  please help find good home
# Predicted Emotion: sadness (Probability: 0.62)
#
# Text: murdered mother  spookytv
# Predicted Emotion: fear (Probability: 0.62)
#
# Text: symmetry key  everything must aesthetically pleasing possible  hold twin pistols   deaththekid  bot
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: caballero s passing remains absolutely dreadful see
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: regret inconvenience caused  noted concern  get touch soon discuss  rgds  abhijit
# Predicted Emotion: fear (Probability: 0.90)
#
# Text: dilemma  wear   sanfran foggy   sacramento cple hrs sun  degr
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: ditto   amazing atmosphere   philippplein  cheerleaders  stunt  londonevents  cheer
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: thomas  nervousness group s focus evident    gt
# Predicted Emotion: fear (Probability: 0.65)
#
# Text: getting comedic relief w season premiere  modernfamily  girl needs   hilarious
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: home heart lies  love little island birth city ai nt acting right  amp  im feeling good  restless
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: goddamn headache   anger
# Predicted Emotion: neutral (Probability: 0.64)
#
# Text: god knows things happen  sometimes s hard understand   sad  prayingforyou
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text:  quot  hi im jonathan spotify    month u cn unlimited music w interuptions  quot  luv r little chats j  dont leave
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: happy birthday seed        renewtherivalry  imyourdaddy  cantbeatme  tater
# Predicted Emotion: anger (Probability: 0.71)
#
# Text: tikcets     want go
# Predicted Emotion: fear (Probability: 0.54)
#
# Text: ca nt stop smiling
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: mi  y em mi   torrent thi   bi   ch  tri  n nhi    ang thii  n long l  ch  xu  ng   u tra
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: liver elated nt us
# Predicted Emotion: joy (Probability: 1.00)
#
# Text:   amp  s one nt like mine comes patchy  s dark color tho
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: bad  slash prices send refugee camps  like team gear lose championships   awful
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: ca nt make nyc m huh
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: round way  ahve copy public contacts personal contacts first  big deal
# Predicted Emotion: anger (Probability: 0.45)
#
# Text: gleesome threesome
# Predicted Emotion: neutral (Probability: 0.57)
#
# Text: bought pack two medallion beef steaks  got home  cooked  one steak   pork  one unhappy mother
# Predicted Emotion: neutral (Probability: 0.52)
#
# Text: oh yes  males colourful females dull  blend environment
# Predicted Emotion: sadness (Probability: 0.84)
#
# Text: need  bust elites dc  need jobs   need clean blithe inner cities  rebuild housing  cont
# Predicted Emotion: neutral (Probability: 0.36)
#
# Text: pretty average  klitschko fury k joshua white k
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: hahaha nt know anyone anything except powers lol  live bubble
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: halloween party coming soon   turnt  ruint  lit  firesauce  hotsauce  mildsauce  getsauced  champagnedreams  scary  haunt  kittens
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: news disheartening  everything going result lack understanding misinformation media   sadness
# Predicted Emotion: sadness (Probability: 0.98)
#
# Text: love  memories randomly popninto head   smiling like ann  idiot ages
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: jv girls earn w vs stonington  today  goals k waite winakor   assist
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: omg  ve got watch new series this us   wow  best tv show ve seen long timen  tears  laughter  moretears
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: procrasting fun im hour away time due still havent finished panic attack
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: tvgirl like m really pretty melancholic life hate
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: inha s seol s banter rly fun read  im awe seol willing deal tho
# Predicted Emotion: fear (Probability: 0.88)
#
# Text: peanut butter     kinda pervert    awful
# Predicted Emotion: neutral (Probability: 0.73)
#
# Text: dean really saving lot ppl  bc nt snap nomore  amp  take much
# Predicted Emotion: anger (Probability: 0.96)
#
# Text: show sucks   lame  awful even used names   lol bad   failed  notworthminutes  air soon
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: makes fucking irate jesus  nobody calling ppl like hajime abusive stop strawmen lmao
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: think paul s bitter  pastry
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: goddamn headache
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: surfer girl nt speak language anymore   justsaying  sadness
# Predicted Emotion: sadness (Probability: 0.88)
#
# Text: let know s
# Predicted Emotion: sadness (Probability: 0.98)
#
# Text: people hate nothing happy confident person  never mind  happy  confident
# Predicted Emotion: joy (Probability: 1.00)
#
# Text:  problem  yes   something    worry
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: lovely story actually see ruth hubby cashcow funny left phone  happy
# Predicted Emotion: sadness (Probability: 0.65)
#
# Text: s gloomy outside  wish cold looked
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: tones  n   favourite chris pine stans  love tones anything  mt sweet summer child attack anyone hurts
# Predicted Emotion: anger (Probability: 0.34)
#
# Text: sober better roll another dutch u nt smoke nigga better pour another cup
# Predicted Emotion: sadness (Probability: 0.89)
#
# Text: rangers v celtic  revenge
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  degrees would dream  s  boise still
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: s stupid  hate lol
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: cancelled cbs access live feeds jc even said vic afp  paulshould imo  bitter
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: golden ocean day lush  gagged sick  waste PS  fuming miss
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: resorted eating mickey ds alone
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: four full days left aussieland  nt want go home
# Predicted Emotion: neutral (Probability: 0.93)
#
# Text: funny want something even  someone else cant anymore hahaha next
# Predicted Emotion: neutral (Probability: 0.94)
#
# Text: spend even  minutes already irritate seriously bitch shut
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: benefit exhilaration called online backing  jkuvmvqxy
# Predicted Emotion: neutral (Probability: 0.39)
#
# Text: damnnit  gon na  pts shy chiefs rewards getting post game photo
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: wrath one kill  laughter  friedrich nietzsche  friedrichnietzsche
# Predicted Emotion: anger (Probability: 0.96)
#
# Text: s beautifully sincere balancing act grief hilarity
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: nap day comfortable sleeping night ll never comfortable
# Predicted Emotion: fear (Probability: 0.84)
#
# Text: way laser vista  lens implantation   laservista  happy
# Predicted Emotion: fear (Probability: 0.57)
#
# Text: add donte moncrief dismal situation  blessed
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: totally get  ve said donuts  times one week lost  lbs get discouraged  s linear
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: fuck madden way harder
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: ve contacted  service  whathappenedtocustomerservice
# Predicted Emotion: fear (Probability: 0.93)
#
# Text: penny dreadful cleaved fraction heart
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: stay jaded everyone
# Predicted Emotion: fear (Probability: 0.85)
#
# Text: lord turn face toward give peace  numbers   truth  trust  promise  calm  justice  great  mighty  protected
# Predicted Emotion: joy (Probability: 0.97)
#
# Text: oh get see s  texastech playing tonight  texans  tnf  texansarebad  terrible
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: watching jubilant scrum end day remembering re still kids   priceless
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: hearty italian man
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: m working bit
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: thing feed naay raging something brother filling gaps
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: wish could say weather mumbai  hot n horrible guess friday one reason
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: leg feels like s gon na burst  yet m still expected go work
# Predicted Emotion: anger (Probability: 0.57)
#
# Text: dreading history coursework monday
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: everyone raging
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: heading bed  somewhat reluctantly  look around  must dvds region
# Predicted Emotion: neutral (Probability: 0.86)
#
# Text: let know s  blues
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: food gets delivered
# Predicted Emotion: neutral (Probability: 0.96)
#
# Text: android app designed buggy work sporadically fire tv box
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: re reason ca nt get boc
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: sam yes  helpful  need sorting asap  keep promising stuff nt happen      fuming
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: everything ve ever wanted side fear  george addair  thursdaythoughts  yourpushfactor  fear  life  quote
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: batman animated series gift s animation gods
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: stinks anyway
# Predicted Emotion: neutral (Probability: 0.76)
#
# Text: hahah tiff sent
# Predicted Emotion: neutral (Probability: 0.71)
#
# Text: hope go away quicker mine   weeks counting
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text:   tmobile  stores   original  note  customer zero  results  s going guys   terrible  customerservice  hour  waittime
# Predicted Emotion: fear (Probability: 1.00)
#
# Text:  getting banned still lurk corners underneath bed sofa  much eyepatch s delight
# Predicted Emotion: joy (Probability: 0.69)
#
# Text: yall shabazz s name phone easy breezy beautiful   amp  apologize
# Predicted Emotion: joy (Probability: 0.98)
#
# Text: would nt bring  s touchy subject  people get way offended days
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: skiving  freshers day   nails  sunbeds  gym  priorities  student  studentnurse  pampered  happy
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: wnna take bath
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: oooo ok havent accepted friends request
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: isaiah nthose trust lord find new strengthnthey soar high wings like eaglesnthey run grow weary
# Predicted Emotion: sadness (Probability: 0.96)
#
# Text: love cheerful woman storing someone else s furniture eternity  d sold   granddesigns
# Predicted Emotion: joy (Probability: 0.95)
#
# Text: joke
# Predicted Emotion: fear (Probability: 0.99)
#
# Text: pm  sheikhhasina speech terms  terrorism global challenge urges world leaders work together unroot everywhere
# Predicted Emotion: fear (Probability: 0.99)
#
# Text: jeans fake pockets
# Predicted Emotion: neutral (Probability: 0.51)
#
# Text: actually  time get  train would arrived
# Predicted Emotion: anger (Probability: 0.79)
#
# Text: asian tiger  mosquitoes relentless  aggressive kind dealt was kid
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: really put pic  guess
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: iniesta still one player idolize barca  delight watch tell
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: woke watched jon kate plus eight  tried pretend like still normail family
# Predicted Emotion: neutral (Probability: 0.86)
#
# Text: wished sis  midnight received reply  nd sis wished  got reply  know s fav  offended
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:   goal scorer vidar kjartansson comes favor dor micha  another terrific performance  yallamaccabi
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: let us burden remembrances heaviness s gonen william shakespeare    n  forge ahead
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: think highprofile female colleague would one yhat category   massexodus  bitter
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: looks like  india finally taking  pakistan n s  terrorism task  uriattacks
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: remember joey slagging england player s bringing books crap tournaments   crap player  bully
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: began squirm beneath struggling get relentless grasp  realized attempt useless
# Predicted Emotion: anger (Probability: 0.97)
#
# Text: lil reminder private account delight shittalking occasionally nsfw stuff
# Predicted Emotion: neutral (Probability: 0.73)
#
# Text: depressing shit ever
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: s insult
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: tomorrow day cut dye hair   excited
# Predicted Emotion: fear (Probability: 0.95)
#
# Text: hopefully ll get best buy job  officaly  start  streaming  career  working towards something love  dayatatime
# Predicted Emotion: neutral (Probability: 0.85)
#
# Text: looking back recent tweets seen  one right great  perfect  hilarious  speechless  deal
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: john magic box   lost
# Predicted Emotion: sadness (Probability: 0.70)
#
# Text: wishes could special someone
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: fuking fuming
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: still waiting see make appearance next week  two months today ordered  badservice
# Predicted Emotion: fear (Probability: 0.96)
#
# Text: worst thing confimation
# Predicted Emotion: neutral (Probability: 0.45)
#
# Text: bitter hurts lmaooo
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: grow weary
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: thoroughly enjoying ahs tonight   ahs  americanhorrorstory
# Predicted Emotion: fear (Probability: 0.96)
#
# Text: athenian  mirth order day  ought honoured gives mirth greatest number  laws
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: really care like state would seriously address sensitivity training employees  awful
# Predicted Emotion: fear (Probability: 0.73)
#
# Text: let s rage
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  excitement weekend pure dread
# Predicted Emotion: fear (Probability: 0.97)
#
# Text: asshole  made sexually attacked animated bear  p
# Predicted Emotion: joy (Probability: 0.81)
#
# Text: gerrard awful
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: come glasgow night working  fucking gutted  waiting appearance ages
# Predicted Emotion: neutral (Probability: 0.77)
#
# Text: find initiative nt even thing  revenge
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: much outrage oh  using female body sell something
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: s  dm nt follow   delight  party  fail  letdown
# Predicted Emotion: anger (Probability: 0.85)
#
# Text: downloading tf  mere g    nearly instantly kb
# Predicted Emotion: anger (Probability: 0.81)
#
# Text: especially comes voicing displeasure  ca nt tell straight hold peace
# Predicted Emotion: anger (Probability: 0.94)
#
# Text: bts  hwayangyeonhwa trilogy mv time fav quite gloomy beautiful well
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: research come new insult  allowed read anything brietbart
# Predicted Emotion: anger (Probability: 0.46)
#
# Text: point scorning fury labor nothing address long term detention need resettle  asylumseekers  manus  nauru
# Predicted Emotion: neutral (Probability: 0.92)
#
# Text: james  k  k  k  k  fucked   bb  bitter  shouldofvotedfornicole
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: flight  crashed lost island   lost
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: becoming boiling hot  slowly melting  heart frozen
# Predicted Emotion: anger (Probability: 0.91)
#
# Text: candice s standing pout face aggravates every week
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: geoff posted boo  coming home tenerife boo
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: re welcome   wordgeek nalso  good put face twitter feed  even cheery hello
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: help maintain boost status world class centre education  culture tolerance
# Predicted Emotion: fear (Probability: 0.47)
#
# Text: eating lunch  school
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: one favorite classic cars plymouth fiery
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: even forget pick ur fave child school
# Predicted Emotion: anger (Probability: 0.49)
#
# Text: praying  ryan smith  amp   amp  mike fernandez
# Predicted Emotion: sadness (Probability: 0.36)
#
# Text: stop horror movie themed commercial  suddenly hearing screams really making want watch twitch
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: people want go pine ridge  little wound oelrichs  starting think transferring wan na stay cloud  decisions man
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: retweeted gunnysmith like today happy alive   blessed  rejoice
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: would like congratulate people saudi arabia happy joyous national day  may great time   lywmlwTny
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: girlfriends cooking dinner  spag blow  sure need help  girlfriends  happy
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: panpiper playing big river outside bridges sr
# Predicted Emotion: anger (Probability: 0.71)
#
# Text:  thtest match would t odi national colors  nightmare  hitter
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: appointment booked  today  waited day nobody showed  also requested call back never got one
# Predicted Emotion: fear (Probability: 0.93)
#
# Text: find today first kiss
# Predicted Emotion: neutral (Probability: 0.64)
#
# Text: probably  yoot nt care grandad
# Predicted Emotion: sadness (Probability: 0.47)
#
# Text: que houve
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text:  indiamissingindira could never solve kashmir problem kept burning vote bankn  terrorstatepak
# Predicted Emotion: anger (Probability: 0.79)
#
# Text: got diagnosed severeextreme depression nt know difference two lol
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text:  hour rides make  sorry
# Predicted Emotion: anger (Probability: 0.44)
#
# Text: m still nervous try  need man give ago
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: irritation level time high today
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: dear hipster behind game finding hard pay attention talk politics grapes wrath  shut
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: draw  scum must rubbing hands glee  typical draw woolwich lot     jammygunnerscum
# Predicted Emotion: joy (Probability: 0.97)
#
# Text: really amazing money give qb s  nfl  texans  brock
# Predicted Emotion: fear (Probability: 0.90)
#
# Text: popufurs make posts like opening commissions hour get slot  m like sitting awe sort demand
# Predicted Emotion: fear (Probability: 0.92)
#
# Text:  pessimist complains wind   optimist expects change  realist adjusts sails    william arthur wardn  ignite
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: s la  wanting sun today  apparently la nt cooperating
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: first weekend fall  let s see stay disciplined seasons goals   fitness  running  sober  mindset  firstfriday  family
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: trying make  betterworld  depressing s  failure
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: well stomach cramps make spin class easier  body hate digesting porridge much  spinning  sulk
# Predicted Emotion: sadness (Probability: 0.91)
#
# Text: lmao person must hate bad talk shit behind anonymous account  awe
# Predicted Emotion: fear (Probability: 0.64)
#
# Text: ohh course  stop though  end dream  john woodvine  amp  zoe thorne  ones signed programme
# Predicted Emotion: joy (Probability: 0.47)
#
# Text: constantly fucking boiling s ok
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: realistic probability clown might next president   clown  uspol  nightmare
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: really really resent go bed sensible hour  guys  want talk people
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: stuck runway diverted fargo  continuously told  mins past  hours  foodwater offered  awful
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: paddy mcnair joint top scorer  yeah  justlet sink haha
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: yep  wish playing dubiln
# Predicted Emotion: anger (Probability: 0.71)
#
# Text: ikr
# Predicted Emotion: neutral (Probability: 0.78)
#
# Text: way  m wearing smile gave today  n    smile
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: live event brock vs orton  saturday wwe network  needs     wwe
# Predicted Emotion: anger (Probability: 0.84)
#
# Text: u laugh today  laugh hard  hope  need laughter   love
# Predicted Emotion: joy (Probability: 0.99)
#
# Text:  less sugar  fruitn less soda  watern less worry  sleepn less words  action
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: nothing bout  go  work
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: s meant
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: pussy weak heard stfu bitch  got threaten pregnant
# Predicted Emotion: fear (Probability: 0.99)
#
# Text: s name mixtape  mixtape connect moved texas got ta find new guy
# Predicted Emotion: fear (Probability: 0.66)
#
# Text: s eyeforeye   indian army never forgives  never forgets  always take revenge  pakistan breaks laws  ia follows
# Predicted Emotion: anger (Probability: 0.74)
#
# Text: day  elated m taking pto tomorrow m doneeeee
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: nothing
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: blame jose ere would give rojo another start sunday  fucking disaster waiting happen  amp  shocking header
# Predicted Emotion: fear (Probability: 0.84)
#
# Text: never make  decision re  angry never make  promise re  happy   wisewords
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: focal points war lie  terrorism  un needs address  violentextremism
# Predicted Emotion: neutral (Probability: 0.86)
#
# Text: s pre industrial revolutionesque footwear  guys tryin grapes wrath today
# Predicted Emotion: anger (Probability: 0.94)
#
# Text: m black   read books  pu kids school  my prayer u wl lv long  fulfilling  joyous  peaceful  godpleasing life
# Predicted Emotion: joy (Probability: 0.97)
#
# Text: red sox team equivalent tiger woods heyday  mercy
# Predicted Emotion: joy (Probability: 0.53)
#
# Text: looove guitars  playing  think sound magnificent  better
# Predicted Emotion: joy (Probability: 0.73)
#
# Text: yes  yes
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: morrissey cancelled
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: u ever jus fell like damn  jus want cake n lay next ur baby  watch movies chill freak night
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: google caffeinean sprightly lengthening corridor seo  wgj
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: virtually every statement countries  un referred  terror main threat peace   pak still denial
# Predicted Emotion: fear (Probability: 0.98)
#
# Text: check  scotland  gamer  youtuber  vlogger  designer  animator  artist  ty following wake  horrorfilm
# Predicted Emotion: neutral (Probability: 0.70)
#
# Text: castlebar doesnt d im going galway see jb d movie could next week one
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: sorry missed   stayed late working pondering life
# Predicted Emotion: sadness (Probability: 0.72)
#
# Text: leave fraser alone
# Predicted Emotion: sadness (Probability: 0.95)
#
# Text: people trying hard hate cam newton without understanding position
# Predicted Emotion: sadness (Probability: 0.90)
#
# Text:  heard talk something miss  looks weary
# Predicted Emotion: anger (Probability: 0.81)
#
# Text: indian army crossed loc pok bust terror camp th sept night
# Predicted Emotion: neutral (Probability: 0.52)
#
# Text: re least known band world  glad asked  muchlove  hilarious
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: worst customer service lack professionalism service provider   phoneprovider  badbusiness  terrible
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: love new show  hilarious
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: years irrelevant  absolute joke   manutd  ticketing  noloyalty  joke  notimpressed
# Predicted Emotion: anger (Probability: 0.85)
#
# Text: way thinking  wants absolute hope born absolute despair
# Predicted Emotion: sadness (Probability: 0.49)
#
# Text: understand concerns look foundation contributions
# Predicted Emotion: fear (Probability: 0.57)
#
# Text: s outrage black man kills another black man streets
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: m saying might like big foot might like natural biological father says blood boiling cross
# Predicted Emotion: anger (Probability: 0.91)
#
# Text: dogs making ridiculous sounds right like high pitched gargley growl
# Predicted Emotion: anger (Probability: 0.69)
#
# Text: hi monica  write regularly  bees  never dared try  buzz  honey
# Predicted Emotion: anger (Probability: 0.75)
#
# Text: u already took da pic
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: let s panic  beat nyg s atop division  come home cleveland  like re  division win
# Predicted Emotion: neutral (Probability: 0.41)
#
# Text: feels good get outside minute get fresh air  s hard stay cooped inside day  breezy
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: well stock finished  amp  listed  living room moved around  new editing done  amp  fitted visit inlaws   productivityatitsfinest  happy
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: must scared trolling  guys sad   tcot  right
# Predicted Emotion: sadness (Probability: 0.78)
#
# Text: ll pity
# Predicted Emotion: neutral (Probability: 0.47)
#
# Text: beer fridge
# Predicted Emotion: neutral (Probability: 0.98)
#
# Text: ve never seen fast  amp  furious tokyo drift  boutta watch
# Predicted Emotion: anger (Probability: 0.99)
#
# Text:  welfarereform model   snap
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: henny pine apples
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: saw note faq languages  thing would change mind  need help anything else
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: yall tune snapchat beans funereal
# Predicted Emotion: anger (Probability: 0.99)
#
# Text: got asked hoco instagram dm bc someone lost bet  love maturity people grade
# Predicted Emotion: anger (Probability: 0.80)
#
# Text: sadness leaves broken bed  hold depths despair  s name love
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: yes  nt discourage
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: nt give someone power letting words offend
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: bored rn leave kiksnapchat  kik  kikme  kikmessage  boredaf  bored  snapchatme  snapchat  country  countrygirl
# Predicted Emotion: anger (Probability: 0.96)
#
# Text: georgia tech s secondary soft marshmallow   horrible
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: three first  weeks june
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: quinn s short hair makes sad
# Predicted Emotion: joy (Probability: 0.80)
#
# Text: peter aesthetically pleasing look
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: excited  people reservation morning damn lovin halo right sure
# Predicted Emotion: fear (Probability: 0.42)
#
# Text: missed bl    bus
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: currently unfollowing anything relating disneyworld florida   holidayblues  depressing  wantogoback
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: one step long work  visa process  relief  onto next step   expat  restless
# Predicted Emotion: neutral (Probability: 0.94)
#
# Text: sometimes worst place head  nn  quotes  worstenemy  thinktoomuch
# Predicted Emotion: sadness (Probability: 0.87)
#
# Text: trying book holiday flights website becoming  nightmare
# Predicted Emotion: fear (Probability: 0.96)
#
# Text: confident bitches scare
# Predicted Emotion: fear (Probability: 0.95)
#
# Text: yeah   uk quite
# Predicted Emotion: neutral (Probability: 0.64)
#
# Text: happened  need smoke   burning
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: aaahhhh  little soothe soul   music
# Predicted Emotion: sadness (Probability: 0.75)
#
# Text: thats thinking time s gon na
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: being   usa  panicattacks  anxiety  depression much medication
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: let  mrrobot binge begin   nerdshow  compelling  dark
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: fine  give  docs today  able breath morning made think  hate docs
# Predicted Emotion: neutral (Probability: 0.92)
#
# Text:  wordsaftersex turn yet
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text:  wasteful day  day without  laughter
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: farting hot car windows nt roll terrible   gag  bresadvice
# Predicted Emotion: fear (Probability: 0.73)
#
# Text: word m always
# Predicted Emotion: joy (Probability: 0.48)
#
# Text: lauren jauregui makes problem dissapear amazes sadness  keeps strong
# Predicted Emotion: sadness (Probability: 0.83)
#
# Text: trying book holiday flights website becoming
# Predicted Emotion: neutral (Probability: 0.87)
#
# Text: speaking ex cobblers  saw ricky holmes charlton last week  tracking back  amp  defending  dread seeing gorre ball
# Predicted Emotion: joy (Probability: 0.50)
#
# Text: btw  really stay bed day today   depression hate lied  fuck liars  w
# Predicted Emotion: sadness (Probability: 0.98)
#
# Text:  teeth sunk vein poor woman accidentally  small problem engine  outside
# Predicted Emotion: sadness (Probability: 0.98)
#
# Text: blm outraged shooting nc day  turns guy pointed gun police  wait facts outrage
# Predicted Emotion: anger (Probability: 0.84)
#
# Text:  yall mean rioting  fire starting  business burning  looting assholes  create  blacklivesmatter
# Predicted Emotion: fear (Probability: 0.76)
#
# Text: july  long
# ...
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: ff later  busy making plans today  beshie gon na dc june  bball game
# Predicted Emotion: neutral (Probability: 0.88)
#
# Text: round   pcola
# Predicted Emotion: fear (Probability: 0.68)
#
# Text: forgot hair straightner home  m feeling lost without   lost  lostwithoutmyhairstraightener
# Predicted Emotion: sadness (Probability: 0.87)
#
# Text: quotesoup  happy everything good  see good side everything
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: dwts make night every show
# Predicted Emotion: joy (Probability: 0.69)
#
# Text:  hate going doctor many levels least go sleep  smile watched  dwight live nation
# Predicted Emotion: neutral (Probability: 0.59)
#
# Text: good thing fbi nt offend
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: watched django unchained  people may frown  titter delight
# Predicted Emotion: sadness (Probability: 0.80)
#
# Text: sadly best days behind
# Predicted Emotion: sadness (Probability: 0.96)
#
# Text:  hours sleep last night barely functioning
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: dream brought kings island  pretty sweet  bummed re poughkeepsie  hours
# Predicted Emotion: fear (Probability: 0.69)
#
# Text: know re slightly high  state sober high af  s beautiful  wish could feel like
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: bc s gloomy day tony
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: using twitter coping mechanism raging kid oops
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: nt shy next time  re cheery bunch    nnsam  x
# Predicted Emotion: joy (Probability: 0.88)
#
# Text: used think fire detector going old place boiling water bad one went bc dust wouldnt turn
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: one step long work  visa process  relief  onto next step   expat
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: huh  s always fault nt  gt     sulk
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: humira nt right everyone  respond better enbrel  ask rheumy  much longterm testing done
# Predicted Emotion: anger (Probability: 0.87)
#
# Text: m still  happy na blast
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: s always  start s  finish
# Predicted Emotion: fear (Probability: 0.97)
#
# Text: everton playing fume day
# Predicted Emotion: anger (Probability: 0.93)
#
# Text: s cause give reason assume
# Predicted Emotion: neutral (Probability: 0.42)
#
# Text: job interview tomorrow  bright side
# Predicted Emotion: fear (Probability: 0.74)
#
# Text: start growing mustache  pablo escobar halloween
# Predicted Emotion: fear (Probability: 0.92)
#
# Text:  epipen  public outrage occurs  expand  pap patient assistance progrm  coupons  rebates  mylan  epipen
# Predicted Emotion: anger (Probability: 0.97)
#
# Text: made night reid included tonight s hilarity  points brilliant  thanks
# Predicted Emotion: neutral (Probability: 0.55)
#
# Text: wont use using   guys cant get nothing right    fuming
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: texans scared bunch
# Predicted Emotion: fear (Probability: 0.99)
#
# Text:  educate child  rich  educate  happy  grow  ll know  value things  price
# Predicted Emotion: fear (Probability: 0.51)
#
# Text: gon na give kkk police bitch minimum sentence  wattch  angry
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  liked moping around episode  moment emotional weakness  felt sorry
# Predicted Emotion: sadness (Probability: 0.83)
#
# Text: s always one song makes turn radio  d rather sit silence  awful
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: one chosen clp members  mp seats people dole mates  elect candidates
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: dont play master noob u want win   serious
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: whats boxes search google chrome  horrible  distracting
# Predicted Emotion: fear (Probability: 1.00)
#
# Text:  sigh   saddness  afterellen  shitsucks
# Predicted Emotion: neutral (Probability: 0.52)
#
# Text: leveled half  much better offense expected second half
# Predicted Emotion: anger (Probability: 0.88)
#
# Text: fault worked hard stayed course eventually paid   let known count
# Predicted Emotion: sadness (Probability: 0.98)
#
# Text: rec d call day haitian church started florida yrs ago  preparing acquire bldg  wanted know   rejoicing
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: gifs ios messaging app hilarious
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: ah sameway  votes   we need vote  d
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: pinterest one dessert  next thing know pinning make  different visually pleasing mouth watering never gon na make sweets
# Predicted Emotion: neutral (Probability: 0.92)
#
# Text: sure  think  revision efforts need s monday
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: watch amazing lively broadcast  musically
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: wow  driveby done rappers mad kicked spiros
# Predicted Emotion: anger (Probability: 0.57)
#
# Text: f breezy
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: tiller breezy collab album  rapping singing prolly fire
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: pro tip  go back work kid reaches  mos old  stay home longer  ll absolutely miserable  tantrums
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  rabid grizzly bears m going scatter neighborhoods americannthey re poor refugees  nn  inyourneighborhoodnotdc
# Predicted Emotion: anger (Probability: 0.57)
#
# Text:  ukedchat a go outside  gym hall  play  n  education  playful  learning
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: friends tell m pretty  trigger tells m ugly  first confused realised m  pretty ugly   tru  sad  tumblr
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: categ gen  amp  obc cost  nill i reservation support  sir minimize fees  bright fut
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: end day got ta  happy
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: baby help math
# Predicted Emotion: neutral (Probability: 0.96)
#
# Text: retweeted dr rand paul fueling middle east arms race worsening already horrific refugee crisis yemen
# Predicted Emotion: fear (Probability: 0.99)
#
# Text: s true  go ways  ve receiving end vegans wrath  lol  personally would nt condemn
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: little nose irritation little chills body  m flu  flu  flu  fallsongs
# Predicted Emotion: anger (Probability: 0.72)
#
# Text: patriot rookie qb jacoby brissett start vs houston tomorrow nitennbeen learning process since got here got ta ready go
# Predicted Emotion: neutral (Probability: 0.53)
#
# Text: addition fiction  wish luck research paper semester   pages  oh boy   daunting
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: ty often conflate two depression  sadness  different  q reminded  mhchat
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: b    er  ncfc grudge match
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: new madden  video gon na xbox ahole going  struggles
# Predicted Emotion: anger (Probability: 0.93)
#
# Text: forever straight fix frown u good
# Predicted Emotion: sadness (Probability: 0.94)
#
# Text: comparing akshay sir zandu balm insult akshay sir
# Predicted Emotion: anger (Probability: 0.86)
#
# Text: s pretty clear ca nt stand tolerance habitual liars  trump fan either s citizen   despair
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: epicurus man least dependent upon morrow goes meet morrow cheerfully
# Predicted Emotion: joy (Probability: 0.92)
#
# Text:  lmfao s  racepimp tamron hall used words fscts  msnbc  sentence  hilarity  libtard  biasedmedia  neverhillary
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: got  serious  hyper  predator  heckler situation
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: lets start
# Predicted Emotion: fear (Probability: 0.57)
#
# Text: currently listening  amp  podcasts   guys please move  yvr   missyou
# Predicted Emotion: joy (Probability: 0.76)
#
# Text: aa right passage comes n  word  insult church  ignorant
# Predicted Emotion: anger (Probability: 0.92)
#
# Text: ve left dad deal work done soon s felt wrath slipper
# Predicted Emotion: anger (Probability: 0.92)
#
# Text: pakis applauding sharif s speech  wonder many really understood said     nthey much excited happy
# Predicted Emotion: joy (Probability: 0.92)
#
# Text:   complained head called despair god s mercy sins go back ask forgiveness
# Predicted Emotion: sadness (Probability: 0.94)
#
# Text: stone cold crazy
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: sitting empty yearbook room  attempting figure asap lol
# Predicted Emotion: anger (Probability: 0.52)
#
# Text: texans scared bunch   intimidated
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: left protected long  ve lost reasoning power
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: cell wo nt hold charge  sadness
# Predicted Emotion: sadness (Probability: 0.56)
#
# Text: tgif  hope everyone needs find  recovery friends stay  sober weekend
# Predicted Emotion: sadness (Probability: 0.75)
#
# Text: stg pine bluff morning piss even  damn shoes came size        know said  fml
# Predicted Emotion: sadness (Probability: 0.45)
#
# Text: person dislikes fall   firstdayoffall  leaves  thingsdie  depressing  cold  noflipflops
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: houston might lose coach tomorrow midnight   yikes
# Predicted Emotion: anger (Probability: 0.72)
#
# Text: unleashing god s wrath cain
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  whaaaat    oh hell  jealous got paid fuck  whole new level   love  conflicted
# Predicted Emotion: anger (Probability: 0.98)
#
# Text: well exam rocked  one go  one ve dreading  bit revision tonight work tomorrow
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: current run superman continues delight  feel love poured everone creative team  superman
# Predicted Emotion: joy (Probability: 0.93)
#
# Text: walked  miles today  ve walked since got  rhabdo  going back work tomorrow  s hoping goes okay
# Predicted Emotion: fear (Probability: 0.80)
#
# Text: leopard never changes spots   lost
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: watch amazing lively broadcast  musically
# Predicted Emotion: joy (Probability: 1.00)
#
# Text: looking window  beautiful blue sky  great forecast weekend  good cinemas
# Predicted Emotion: neutral (Probability: 0.83)
#
# Text: seen coming  s sad  instagram comments pics funny  adapts fans blew
# Predicted Emotion: sadness (Probability: 0.66)
#
# Text: think huffing pine tar use bat gripping
# Predicted Emotion: sadness (Probability: 0.86)
#
# Text: thinking cani  t control thoughts
# Predicted Emotion: anger (Probability: 0.92)
#
# Text: yahoo maps  lots desire  yahoo
# Predicted Emotion: neutral (Probability: 0.84)
#
# Text: favourite quote year far  swore parsnip   raging
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:  azerbaijan  baku azerbaijan prevent another armenian provocation russia
# Predicted Emotion: anger (Probability: 0.56)
#
# Text:  x  x    hear   darn   optimism led    demise     li  live  zerobot
# Predicted Emotion: joy (Probability: 0.77)
#
# Text: cross party group crofting meeting tonight suspect s going lively meeting
# Predicted Emotion: fear (Probability: 0.67)
#
# Text: ooh ve got dvd  never got around watching good
# Predicted Emotion: neutral (Probability: 0.85)
#
# Text: tati  sent emal doll  get
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text: three days month two ex wives home could worse  nt know  could  oilandgas
# Predicted Emotion: joy (Probability: 0.74)
#
# Text:  a   irritation isolation  lifenabler
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: really offer sacrifice daily keep safe    sad
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: today  un armed silence  lungs rejoice freedom  insides color  woman counted  jawbone became razor  free
# Predicted Emotion: joy (Probability: 0.56)
#
# Text: yell  bye  garbage   cheerfully
# Predicted Emotion: joy (Probability: 0.95)
#
# Text: tired restless community  human tired asking change ignored
# Predicted Emotion: fear (Probability: 0.79)
#
# Text: m honestly upset rewarded nicole k   depressing  paulwasrobbed  rewardhardwork  bitterjury  bb
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: life changing redhead  got away
# Predicted Emotion: neutral (Probability: 0.60)
#
# Text: jeans fake pockets  horrible
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: hey handsome  m packing
# Predicted Emotion: neutral (Probability: 0.75)
#
# Text: maybe break smaller bits  space doesnt seem daunting
# Predicted Emotion: neutral (Probability: 0.75)
#
# Text: cosplaying properly first time saturday  pretty nervous
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: re unhappy someone fucking tell re unhappy leave  nt go fuckin around people side
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: cant fall asleep
# Predicted Emotion: neutral (Probability: 0.57)
#
# Text: seeing alex revells face gets angry
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: nice  u fuming
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: unmatched party specialist co  serious  job  titles
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: ha yes look despair
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: getting ready work  working weekend
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: aside m pleasing individual m involved  pleasure comes pleasure
# Predicted Emotion: joy (Probability: 0.95)
#
# Text:  followers  follow ll love    pouts  please
# Predicted Emotion: neutral (Probability: 0.97)
#
# Text: true none players cops  drink chilled bitter  players walter mitty types
# Predicted Emotion: anger (Probability: 1.00)
#
# Text:
# Predicted Emotion: neutral (Probability: 0.95)
#
# Text: food gets delivered  cheering  happy
# Predicted Emotion: joy (Probability: 0.99)
#
# Text: medhurst play
# Predicted Emotion: neutral (Probability: 0.64)
#
# Text: dont feel grateful grateful  written  things work together good  love god
# Predicted Emotion: joy (Probability: 0.95)
#
# Text:  court
# Predicted Emotion: neutral (Probability: 0.68)
#
# Text: memphis looking bright  rojo looking like rojo
# Predicted Emotion: joy (Probability: 0.94)
#
# Text: way work
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: know  nt want left home weekend
# Predicted Emotion: neutral (Probability: 1.00)
#
# Text: hate ideas afraid share
# Predicted Emotion: fear (Probability: 0.99)
#
# Text: sorry main twitter im depress
# Predicted Emotion: sadness (Probability: 1.00)
#
# Text: evidently feels  norms  show  tax return  nothing
# Predicted Emotion: fear (Probability: 0.77)
#
# Text: m  nervous test rip
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: walk darkness despondency  scverses ve memorized shine light heart  ex  lam
# Predicted Emotion: anger (Probability: 0.47)
#
# Text: bad news fam  life still hard awful  depression  atleastihavebuffy
# Predicted Emotion: sadness (Probability: 0.99)
#
# Text: actual nightmare
# Predicted Emotion: fear (Probability: 1.00)
#
# Text:  days  never fucking pen      nffc  bitter
# Predicted Emotion: anger (Probability: 1.00)
#
# Text: s worst affliction someone know ever convinced
# Predicted Emotion: sadness (Probability: 0.97)
#
# Text: gah forgot separate bins  maybe bad idea
# Predicted Emotion: neutral (Probability: 0.99)
#
# Text:  india right reply  unga   pakistan preaching human rights country global epicentre
# Predicted Emotion: fear (Probability: 0.96)
#
# Text: this sadly history teacher talked fuck remember
# Predicted Emotion: sadness (Probability: 0.67)
#
# Text: pumped interview  nervous
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: follow amazing australian author  fiction  horror  zombies  angels  demons  vampires  werewolves  follow  authorlove
# Predicted Emotion: fear (Probability: 1.00)
#
# Text: please tell us protesting  injustice requires  burning  beating  looting terrible optics  toussaintromain true leader
# Predicted Emotion: fear (Probability: 0.67)

# %%
emotions = [
    "I hate getting up, it's so annoying.",
    "I love cats and their sweet noses.",
    "I put up with my schoolmates.",
    "This movie made me feel so happy!",
    "The traffic jam today was frustrating.",
    "Spending time with friends always brings joy.",
    "I feel lonely when I'm alone at home.",
    "Excited about the upcoming vacation!",
    "I love spending time with friends and family. It brings me so much joy!",
    "The rude behavior of that person made me really angry.",
    "I'm feeling neutral about the upcoming changes at work.",
    "Today is just another neutral day for me.",
    "The constant delays and issues with the project are making me angry.",
    "Winning the lottery would bring me immense joy and happiness!",
    "I don't have a strong opinion on the matter; I'm feeling quite neutral.",
    "The news about the recent event left me in deep sadness.",
    "Losing a loved one is an experience filled with sadness and grief.",
    "I have a neutral stance on the current political situation.",
    "I'm so happy right now!", "This is really frustrating."
    "Feeling sad and lonely tonight.",
    "I can't contain my excitement!",
    "Angry about the recent events.",
    "Today is a wonderful day!",
    "Dealing with a lot of stress.",
    "The movie made me cry, but it was beautiful.",
    "I'm thrilled about the upcoming project.",
    "Feeling a bit anxious about the presentation."
]

texts = []
predicted_emotions_mlp = []
probabilities_mlp = []

for text in emotions:
    vectorized_text = vectorizer.transform([preprocess_text(text)])
    # vectorized_text = vectorizer.transform([text])
    predictions_proba_mlp = mlp_model.predict_proba(vectorized_text)

    predicted_emotion_mlp = label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
    probability_mlp = predictions_proba_mlp.max()

    texts.append(text)
    predicted_emotions_mlp.append(predicted_emotion_mlp)
    probabilities_mlp.append(probability_mlp)

emotion_df_mlp = pd.DataFrame({'Text': texts, 'Predicted Emotion (MLP)': predicted_emotions_mlp, 'Probability (MLP)': probabilities_mlp})

emotion_df_mlp
# Out:
#                                                  Text Predicted Emotion (MLP)  \
# 0                I hate getting up, it's so annoying.                 sadness
# 1                  I love cats and their sweet noses.                     joy
# 2                       I put up with my schoolmates.                   anger
# 3                   This movie made me feel so happy!                     joy
# 4              The traffic jam today was frustrating.                   anger
# 5       Spending time with friends always brings joy.                 sadness
# 6               I feel lonely when I'm alone at home.                 neutral
# 7                Excited about the upcoming vacation!                 neutral
# 8   I love spending time with friends and family. ...                 sadness
# 9   The rude behavior of that person made me reall...                   anger
# 10  I'm feeling neutral about the upcoming changes...                 neutral
# 11          Today is just another neutral day for me.                 neutral
# 12  The constant delays and issues with the projec...                   anger
# 13  Winning the lottery would bring me immense joy...                 sadness
# 14  I don't have a strong opinion on the matter; I...                   anger
# 15  The news about the recent event left me in dee...                 sadness
# 16  Losing a loved one is an experience filled wit...                 sadness
# 17  I have a neutral stance on the current politic...                 sadness
# 18                            I'm so happy right now!                     joy
# 19  This is really frustrating.Feeling sad and lon...                 sadness
# 20                     I can't contain my excitement!                 neutral
# 21                     Angry about the recent events.                   anger
# 22                          Today is a wonderful day!                 neutral
# 23                      Dealing with a lot of stress.                 neutral
# 24       The movie made me cry, but it was beautiful.                   anger
# 25           I'm thrilled about the upcoming project.                 neutral
# 26      Feeling a bit anxious about the presentation.                 neutral
#
#     Probability (MLP)
# 0            0.668173
# 1            0.978282
# 2            0.314527
# 3            0.846680
# 4            0.879346
# 5            0.499188
# 6            0.999533
# 7            0.984509
# 8            0.553618
# 9            0.978150
# 10           0.907447
# 11           0.567925
# 12           0.991595
# 13           0.450675
# 14           0.697782
# 15           0.998093
# 16           0.983410
# 17           0.696856
# 18           0.989685
# 19           0.553464
# 20           0.427548
# 21           0.720185
# 22           0.590147
# 23           0.397615
# 24           0.536779
# 25           0.987162
# 26           0.717741

# %%
text = "Today is a wonderful day!	"

vectorized_text = vectorizer.transform([text])

predictions_proba_mlp = mlp_model.predict_proba(vectorized_text)

predicted_emotion_mlp = label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
probability_mlp = predictions_proba_mlp.max()

sorted_probabilities = sorted(zip(label_encoder.classes_, predictions_proba_mlp.flatten()), key=lambda x: x[1], reverse=True)

print(f"Text: {text}\nPredicted Emotion (MLP): {predicted_emotion_mlp}\nProbability (MLP): {probability_mlp:.2f}")
print(f"Probabilities per class: {sorted_probabilities}")
# Out:
# Text: Today is a wonderful day!
# Predicted Emotion (MLP): neutral
# Probability (MLP): 0.59
# Probabilities per class: [('neutral', 0.5901470760279687), ('joy', 0.39473060236952245), ('sadness', 0.0073791822165468045), ('fear', 0.005896632866009409), ('anger', 0.0018465065199527284)]

# %%
text = """The air crackles with tension, and the world feels like a pressure cooker about to explode. Every step is heavy, and the rhythm of life echoes with the discordant beats of frustration. It's as if the very air is charged with an unsettling energy, ready to unleash the storm that brews within.

The smallest inconveniences become fuel for the fiery furnace of anger, each frustration adding another log to the burning resentment. Words hang in the air, sharp and cutting, like daggers seeking release from the depths of irritation. The world seems painted in shades of red, a visual representation of the simmering rage beneath the surface.

In this moment, control feels elusive, slipping through clenched fists like sand. The desire to scream or slam doors becomes a tempting release, an outlet for the building resentment. The very fabric of patience feels threadbare, stretched to its limit, threatening to unravel at the slightest provocation."""

vectorized_text = vectorizer.transform([text])

predictions_proba_mlp = mlp_model.predict_proba(vectorized_text)

predicted_emotion_mlp = label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
probability_mlp = predictions_proba_mlp.max()

sorted_probabilities = sorted(zip(label_encoder.classes_, predictions_proba_mlp.flatten()), key=lambda x: x[1], reverse=True)

print(f"Text: {text}\nPredicted Emotion (MLP): {predicted_emotion_mlp}\nProbability (MLP): {probability_mlp:.2f}")
print(f"Probabilities per class: {sorted_probabilities}")
# Out:
# Text: The air crackles with tension, and the world feels like a pressure cooker about to explode. Every step is heavy, and the rhythm of life echoes with the discordant beats of frustration. It's as if the very air is charged with an unsettling energy, ready to unleash the storm that brews within.
#
# The smallest inconveniences become fuel for the fiery furnace of anger, each frustration adding another log to the burning resentment. Words hang in the air, sharp and cutting, like daggers seeking release from the depths of irritation. The world seems painted in shades of red, a visual representation of the simmering rage beneath the surface.
#
# In this moment, control feels elusive, slipping through clenched fists like sand. The desire to scream or slam doors becomes a tempting release, an outlet for the building resentment. The very fabric of patience feels threadbare, stretched to its limit, threatening to unravel at the slightest provocation.
# Predicted Emotion (MLP): anger
# Probability (MLP): 0.87
# Probabilities per class: [('anger', 0.8700010798122405), ('sadness', 0.1221130748609173), ('fear', 0.006824049255718758), ('joy', 0.0009794523407141318), ('neutral', 8.234373040918848e-05)]

# %%
text = """In the quietude of solitude, a heavy fog of sadness descends, enveloping the world in a muted palette of gray. Each breath feels like a burden, and the air is thick with the weight of unspoken sorrows. The echo of a distant sigh seems to reverberate through the emptiness, a haunting melody of melancholy.

Every step is laden with the echoes of past heartaches, and the landscape is painted with the brushstrokes of unshed tears. The world, once vibrant and alive, now appears as a desolate tableau, a reflection of the internal storm that rages within. The rhythm of life slows to a somber cadence, mirroring the heavy heart that beats in sync with the sorrowful symphony.

Gazing out through the window, raindrops trace their lonely paths, a metaphor for the tears that refuse to fall. The silence is broken only by the occasional gentle patter, a lullaby for the dispirited soul. The ache is palpable, an emotional bruise that colors every interaction with a tinge of muted blue."""

# Przetworzenie tekstu
vectorized_text = vectorizer.transform([text])

# Predykcja z prawdopodobieństwami
predictions_proba_mlp = mlp_model.predict_proba(vectorized_text)

# Odczytanie emocji z najwyższymi prawdopodobieństwami
predicted_emotion_mlp = label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
probability_mlp = predictions_proba_mlp.max()

# Sortowanie prawdopodobieństw malejąco
sorted_probabilities = sorted(zip(label_encoder.classes_, predictions_proba_mlp.flatten()), key=lambda x: x[1], reverse=True)

# Wyświetlenie wyników
print(f"Text: {text}\nPredicted Emotion (MLP): {predicted_emotion_mlp}\nProbability (MLP): {probability_mlp:.2f}")
print(f"Probabilities per class: {sorted_probabilities}")
# Out:
# Text: In the quietude of solitude, a heavy fog of sadness descends, enveloping the world in a muted palette of gray. Each breath feels like a burden, and the air is thick with the weight of unspoken sorrows. The echo of a distant sigh seems to reverberate through the emptiness, a haunting melody of melancholy.
#
# Every step is laden with the echoes of past heartaches, and the landscape is painted with the brushstrokes of unshed tears. The world, once vibrant and alive, now appears as a desolate tableau, a reflection of the internal storm that rages within. The rhythm of life slows to a somber cadence, mirroring the heavy heart that beats in sync with the sorrowful symphony.
#
# Gazing out through the window, raindrops trace their lonely paths, a metaphor for the tears that refuse to fall. The silence is broken only by the occasional gentle patter, a lullaby for the dispirited soul. The ache is palpable, an emotional bruise that colors every interaction with a tinge of muted blue.
# Predicted Emotion (MLP): sadness
# Probability (MLP): 1.00
# Probabilities per class: [('sadness', 0.9961796476426109), ('anger', 0.0015928691650416822), ('fear', 0.0012854043567608743), ('joy', 0.0008816587025233549), ('neutral', 6.0420133063158075e-05)]

# %%
text = """Waking up to the warm embrace of sunshine, the world seems to sparkle with endless possibilities. A symphony of birdsong dances through the air, creating a melody that resonates with the rhythm of joy. Today is not just a day; it's a canvas waiting to be painted with vibrant hues of happiness.

As I step outside, a gentle breeze carries whispers of optimism, and the flowers in bloom release a fragrance that feels like nature's way of smiling. There's an infectious energy in the atmosphere, a reminder that life is a grand celebration, and every moment is a chance to dance to the melody of our own existence.

In the midst of this symphony of joy, even the mundane becomes extraordinary. The rhythmic tapping of my footsteps on the pavement transforms into a cheerful beat, syncopating with the pulse of life. The world seems to applaud my every move, as if nature itself is cheering me on.

Meeting the gaze of a stranger, there's a shared recognition of the beauty that surrounds us. It's as if joy is a secret language, and we are all fluent in its expression. Laughter becomes the currency of the day, exchanged freely between friends and strangers alike, creating a tapestry of shared happiness."""

vectorized_text = vectorizer.transform([text])

predictions_proba_mlp = mlp_model.predict_proba(vectorized_text)

predicted_emotion_mlp = label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
probability_mlp = predictions_proba_mlp.max()

sorted_probabilities = sorted(zip(label_encoder.classes_, predictions_proba_mlp.flatten()), key=lambda x: x[1], reverse=True)

print(f"Text: {text}\nPredicted Emotion (MLP): {predicted_emotion_mlp}\nProbability (MLP): {probability_mlp:.2f}")
print(f"Probabilities per class: {sorted_probabilities}")
# Out:
# Text: Waking up to the warm embrace of sunshine, the world seems to sparkle with endless possibilities. A symphony of birdsong dances through the air, creating a melody that resonates with the rhythm of joy. Today is not just a day; it's a canvas waiting to be painted with vibrant hues of happiness.
#
# As I step outside, a gentle breeze carries whispers of optimism, and the flowers in bloom release a fragrance that feels like nature's way of smiling. There's an infectious energy in the atmosphere, a reminder that life is a grand celebration, and every moment is a chance to dance to the melody of our own existence.
#
# In the midst of this symphony of joy, even the mundane becomes extraordinary. The rhythmic tapping of my footsteps on the pavement transforms into a cheerful beat, syncopating with the pulse of life. The world seems to applaud my every move, as if nature itself is cheering me on.
#
# Meeting the gaze of a stranger, there's a shared recognition of the beauty that surrounds us. It's as if joy is a secret language, and we are all fluent in its expression. Laughter becomes the currency of the day, exchanged freely between friends and strangers alike, creating a tapestry of shared happiness.
# Predicted Emotion (MLP): joy
# Probability (MLP): 0.63
# Probabilities per class: [('joy', 0.6347893021236535), ('sadness', 0.3567278621325973), ('anger', 0.004453715699386862), ('fear', 0.00392035054387664), ('neutral', 0.00010876950048561887)]

# %%
joblib.dump(mlp_model, 'mlp_model.joblib')
joblib.dump(vectorizer, 'vectorizer.joblib')
joblib.dump(label_encoder, 'label_encoder.joblib')
# Out:
# ['label_encoder.joblib']

# %%
loaded_mlp_model = joblib.load('mlp_model/mlp_model.joblib')
loaded_vectorizer = joblib.load('mlp_model/vectorizer.joblib')
loaded_label_encoder = joblib.load('mlp_model/label_encoder.joblib')

# %%
new_texts_vectorized = loaded_vectorizer.transform(emotions)
predictions_proba_mlp = loaded_mlp_model.predict_proba(new_texts_vectorized)

predicted_emotions_mlp = loaded_label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))
probabilities_mlp = predictions_proba_mlp.max(axis=1)

# %%
new_texts_df_mlp = pd.DataFrame({'Text': emotions, 'Predicted Emotion (MLP)': predicted_emotions_mlp, 'Probability (MLP)': probabilities_mlp})
new_texts_df_mlp
# Out:
#                                                  Text Predicted Emotion (MLP)  \
# 0                I hate getting up, it's so annoying.                 sadness
# 1                  I love cats and their sweet noses.                     joy
# 2                       I put up with my schoolmates.                   anger
# 3                   This movie made me feel so happy!                     joy
# 4              The traffic jam today was frustrating.                   anger
# 5       Spending time with friends always brings joy.                 sadness
# 6               I feel lonely when I'm alone at home.                 neutral
# 7                Excited about the upcoming vacation!                 neutral
# 8   I love spending time with friends and family. ...                 sadness
# 9   The rude behavior of that person made me reall...                   anger
# 10  I'm feeling neutral about the upcoming changes...                 neutral
# 11          Today is just another neutral day for me.                 neutral
# 12  The constant delays and issues with the projec...                   anger
# 13  Winning the lottery would bring me immense joy...                 sadness
# 14  I don't have a strong opinion on the matter; I...                   anger
# 15  The news about the recent event left me in dee...                 sadness
# 16  Losing a loved one is an experience filled wit...                 sadness
# 17  I have a neutral stance on the current politic...                 sadness
# 18                            I'm so happy right now!                     joy
# 19  This is really frustrating.Feeling sad and lon...                 sadness
# 20                     I can't contain my excitement!                 neutral
# 21                     Angry about the recent events.                   anger
# 22                          Today is a wonderful day!                 neutral
# 23                      Dealing with a lot of stress.                 neutral
# 24       The movie made me cry, but it was beautiful.                   anger
# 25           I'm thrilled about the upcoming project.                 neutral
# 26      Feeling a bit anxious about the presentation.                 neutral
#
#     Probability (MLP)
# 0            0.668173
# 1            0.978282
# 2            0.314527
# 3            0.846680
# 4            0.879346
# 5            0.499188
# 6            0.999533
# 7            0.984509
# 8            0.553618
# 9            0.978150
# 10           0.907447
# 11           0.567925
# 12           0.991595
# 13           0.450675
# 14           0.697782
# 15           0.998093
# 16           0.983410
# 17           0.696856
# 18           0.989685
# 19           0.553464
# 20           0.427548
# 21           0.720185
# 22           0.590147
# 23           0.397615
# 24           0.536779
# 25           0.987162
# 26           0.717741

# %%
text = "Today is a wonderful excitement day!"

vectorized_text = loaded_vectorizer.transform([text])

predictions_proba_mlp = loaded_mlp_model.predict_proba(vectorized_text)

predicted_emotion_mlp = loaded_label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
probability_mlp = predictions_proba_mlp.max()

sorted_probabilities = sorted(zip(loaded_label_encoder.classes_, predictions_proba_mlp.flatten()), key=lambda x: x[1], reverse=True)

print(f"Text: {text}\nPredicted Emotion (MLP): {predicted_emotion_mlp}\nProbability (MLP): {probability_mlp:.2f}")
print(f"Probabilities per class: {sorted_probabilities}")
# Out:
# Text: Today is a wonderful excitement day!
# Predicted Emotion (MLP): joy
# Probability (MLP): 0.55
# Probabilities per class: [('joy', 0.5467388154398466), ('neutral', 0.42909937935489956), ('fear', 0.009046685532117476), ('anger', 0.00784323225774115), ('sadness', 0.007271887415395174)]

# %%
text = "I'm afraid of spiders, they're so big!"

vectorized_text = loaded_vectorizer.transform([text])

predictions_proba_mlp = loaded_mlp_model.predict_proba(vectorized_text)

predicted_emotion_mlp = loaded_label_encoder.inverse_transform(predictions_proba_mlp.argmax(axis=1))[0]
probability_mlp = predictions_proba_mlp.max()

sorted_probabilities = sorted(zip(loaded_label_encoder.classes_, predictions_proba_mlp.flatten()), key=lambda x: x[1], reverse=True)

print(f"Text: {text}\nPredicted Emotion (MLP): {predicted_emotion_mlp}\nProbability (MLP): {probability_mlp:.2f}")
print(f"Probabilities per class: {sorted_probabilities}")
# Out:
# Text: I'm afraid of spiders, they're so big!
# Predicted Emotion (MLP): fear
# Probability (MLP): 1.00
# Probabilities per class: [('fear', 0.9955663765811396), ('joy', 0.001988868583259859), ('neutral', 0.0013367213432342962), ('sadness', 0.0006303588872657137), ('anger', 0.00047767460510064215)]
